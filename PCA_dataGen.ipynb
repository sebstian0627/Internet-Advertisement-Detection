# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Synthetic_data_final.csv')
da=df.values
da
# Out:
# array([[0.23138456, 0.37591104, 0.05000739, ..., 0.        , 0.        ,
#         0.        ],
#        [0.12989747, 0.79156641, 0.16610776, ..., 0.        , 0.        ,
#         0.        ],
#        [0.0940785 , 0.50315248, 0.14612732, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.13437484, 0.50799977, 0.09670194, ..., 0.        , 0.        ,
#         0.        ],
#        [0.08102663, 0.40973604, 0.14179658, ..., 0.        , 0.        ,
#         0.        ],
#        [0.10855515, 0.50417562, 0.12050345, ..., 0.        , 0.        ,
#         0.        ]])

# %%
X=da[:,:-1]
y=da[:,-1]

# %%
def PCA(X , k):    
    X_shifted = X - np.mean(X , axis = 0)
    sigma = np.cov(X_shifted , rowvar = False)
    eigen_values , eigen_vectors = np.linalg.eigh(sigma)
    sorted_index = np.argsort(eigen_values)[::-1]
    sorted_eigenvalue = eigen_values[sorted_index]
    sorted_eigenvectors = eigen_vectors[:,sorted_index]
    eigenvector_subset = sorted_eigenvectors[:,0:k]
    X_reduced = np.dot(eigenvector_subset.transpose() , X_shifted.transpose() ).transpose()
    return X_reduced

# %%
new_X = PCA(X, 15)

# %%
print(new_X.shape)
X.shape
# Out:
# (4107, 15)
# (4107, 1558)

# %%
y = np.reshape(y, (y.shape[0], 1))

# %%
data = np.append(new_X, y, axis = 1)

# %%
dataFrame = pd.DataFrame(data)

# %%
# dataFrame[15].sum()

# %%
dataFrame.to_csv('pca_data.csv', index = False)
