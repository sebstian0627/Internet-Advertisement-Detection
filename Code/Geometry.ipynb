# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import collections
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import  cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline
# import os
# os.listdir()

# %%
df=pd.read_csv('Synthetic_data_final.csv')
df.head()
# Out:
#      height     width    aratio  ...  caption*for  caption*you  output_nonad
# 0  0.231385  0.375911  0.050007  ...          0.0          0.0           0.0
# 1  0.129897  0.791566  0.166108  ...          0.0          0.0           0.0
# 2  0.094078  0.503152  0.146127  ...          0.0          0.0           0.0
# 3  0.134375  0.791566  0.159498  ...          0.0          0.0           0.0
# 4  0.134375  0.791566  0.159498  ...          0.0          0.0           0.0
#
# [5 rows x 1559 columns]

# %%
datapd=df[['height','width','aratio','local','output_nonad']]
datapd.describe()
# Out:
#             height        width       aratio        local  output_nonad
# count  4107.000000  4107.000000  4107.000000  4107.000000   4107.000000
# mean      0.142475     0.454755     0.099448     0.781105      0.666667
# std       0.067814     0.174634     0.075806     0.413547      0.471462
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.098556     0.333497     0.055374     1.000000      0.000000
# 50%       0.134375     0.392266     0.079613     1.000000      1.000000
# 75%       0.164224     0.504364     0.138437     1.000000      1.000000
# max       1.000000     1.000000     1.000000     1.000000      1.000000

# %%
fig,ax=plt.subplots(nrows=2,ncols=3)
fig.set_figheight(5)
fig.set_figwidth(13)
h=datapd['height']
sns.distplot(h[datapd['output_nonad']==0],ax=ax[0,0])
sns.distplot(h[datapd['output_nonad']==1],ax=ax[1,0])
h=datapd['width']
sns.distplot(h[datapd['output_nonad']==0],ax=ax[0,1])
sns.distplot(h[datapd['output_nonad']==1],ax=ax[1,1])
h=datapd['aratio']
sns.distplot(h[datapd['output_nonad']==0],ax=ax[0,2])
sns.distplot(h[datapd['output_nonad']==1],ax=ax[1,2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.violinplot(x="output_nonad", y="height",data=datapd,split=True,inner="quart")

# %%
dddd=datapd.drop('height',axis=1)

# %%
dddd.head()
# Out:
#       width    aratio  local  output_nonad
# 0  0.375911  0.050007    1.0           0.0
# 1  0.791566  0.166108    1.0           0.0
# 2  0.503152  0.146127    1.0           0.0
# 3  0.791566  0.159498    1.0           0.0
# 4  0.791566  0.159498    1.0           0.0

# %%
# print("                                              add/non-ad  vs   Features")
# fig,ax=plt.subplots(nrows=4,ncols=1)
# fig.set_figheight(15)
# fig.set_figwidth(18)
# sns.stripplot(y='output_nonad',x='height',data=datapd,ax=ax[0])
# sns.stripplot(y='output_nonad',x='width',data=datapd,ax=ax[1])
# sns.stripplot(y='output_nonad',x='aratio',data=datapd,ax=ax[2])
# sns.stripplot(y='output_nonad',x='local',data=datapd,ax=ax[3])
# plt.show()

# %%
columns_for_visualization = list()
columns_for_visualization=['height','width','aratio','local']
corr=datapd[columns_for_visualization].corr()
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(corr,annot=True,linewidths=.5, ax=ax)

# %%
da=dddd.values
X=da[:,:-1]
y=da[:,-1]


xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.30,random_state=80)

# %%
def fit_models(classifiers,xtrain,ytrain):
    """This function fit multiple models by sklearn and return the dictionary with values as  objects of models"""
    models=collections.OrderedDict()
    for constructor in classifiers:
        obj=constructor()
        obj.fit(xtrain,ytrain)
        models[str(constructor).split(':')[0]]=obj
    return models

def classification_multi_report(ytest,models_array):
    """This function generate classification accuracy report for given input model objects"""
    for i in models_array:
        print('__________________________________________________')
        print('the model - '+str(i))
        print(classification_report(ytest,models_array[i].predict(xtest)))
def cross_Fucntion(models,cv):
    """This function return cross validated accuray and the variance of given input model obejects"""
    accuracy={}
    for model in models:
        cross_val_array=cross_val_score(models[model],xtrain,ytrain,scoring='accuracy',cv=cv)
        accuracy[model]=[np.mean(cross_val_array),np.std(cross_val_array)]
    return accuracy

def multi_grid_search(param_grid_array,estimator_list,x,y):
    """This function calculate the grid search parameters and accuracy  for given input modles and return dictionary with each tupple containing accuracy and best parameters"""
    d={}
    count=0
    for i in estimator_list:
        gc=GridSearchCV(estimator=estimator_list[i],param_grid=param_grid_array[count],scoring ='accuracy',cv=5).fit(x,y)
        d[i]=(gc.best_params_,gc.best_score_)
        count+=1
    return d

# %% [markdown]
# ## Classification  Report
#
# >The classification report visualizer displays the precision, recall, F1, and support scores for the model. ... Visual classification reports are used to compare classification models to select models that are “redder”, e.g. have stronger classification metrics or that are more balanced.

# %%
classifiers=[ SVC,KNeighborsClassifier, RandomForestClassifier, GradientBoostingClassifier,LogisticRegression,DecisionTreeClassifier]

model_list=fit_models(classifiers,xtrain,ytrain)

classification_multi_report(ytest,model_list)
# Out:
# __________________________________________________
# the model - <class 'sklearn.svm._classes.SVC'>
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.53      0.68       409
#          1.0       0.81      0.99      0.89       824
#
#     accuracy                           0.84      1233
#    macro avg       0.88      0.76      0.79      1233
# weighted avg       0.86      0.84      0.82      1233
#
# __________________________________________________
# the model - <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.84       409
#          1.0       0.92      0.93      0.92       824
#
#     accuracy                           0.90      1233
#    macro avg       0.89      0.88      0.88      1233
# weighted avg       0.90      0.90      0.90      1233
#
# __________________________________________________
# the model - <class 'sklearn.ensemble._forest.RandomForestClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.85      0.88       409
#          1.0       0.93      0.96      0.94       824
#
#     accuracy                           0.92      1233
#    macro avg       0.92      0.91      0.91      1233
# weighted avg       0.92      0.92      0.92      1233
#
# __________________________________________________
# the model - <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.72      0.81       409
#          1.0       0.88      0.97      0.92       824
#
#     accuracy                           0.89      1233
#    macro avg       0.90      0.85      0.87      1233
# weighted avg       0.89      0.89      0.89      1233
#
# __________________________________________________
# the model - <class 'sklearn.linear_model._logistic.LogisticRegression'>
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.56      0.70       409
#          1.0       0.82      0.97      0.89       824
#
#     accuracy                           0.84      1233
#    macro avg       0.87      0.77      0.79      1233
# weighted avg       0.85      0.84      0.83      1233
#
# __________________________________________________
# the model - <class 'sklearn.tree._classes.DecisionTreeClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.87      0.86       409
#          1.0       0.93      0.93      0.93       824
#
#     accuracy                           0.91      1233
#    macro avg       0.90      0.90      0.90      1233
# weighted avg       0.91      0.91      0.91      1233

# %%
obj=cross_Fucntion(model_list,cv=20)
for model in obj:
    print('the model -'+str(model)+'has \n || crosss validated accuracy as  -> '+str(obj[model][0])+' | variance - '+str(obj[model][1])+' ||' )
    print('______________________________________________________________________________________________________________')
# Out:
# the model -<class 'sklearn.svm._classes.SVC'>has
#  || crosss validated accuracy as  -> 0.8309124902874903 | variance - 0.025552929527984665 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.neighbors._classification.KNeighborsClassifier'>has
#  || crosss validated accuracy as  -> 0.8900641025641025 | variance - 0.02488099509802605 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.ensemble._forest.RandomForestClassifier'>has
#  || crosss validated accuracy as  -> 0.907432498057498 | variance - 0.019884951032696455 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.ensemble._gb.GradientBoostingClassifier'>has
#  || crosss validated accuracy as  -> 0.8799363830613831 | variance - 0.023476159016257204 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.linear_model._logistic.LogisticRegression'>has
#  || crosss validated accuracy as  -> 0.8316045066045066 | variance - 0.026377915796894025 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.tree._classes.DecisionTreeClassifier'>has
#  || crosss validated accuracy as  -> 0.8949130730380732 | variance - 0.023687552167797863 ||
# ______________________________________________________________________________________________________________

# %%
param_grid_svm=[
    {
        'kernel':['linear'],'random_state':[0]
    },
     {
        'kernel':['rbf'],'random_state':[0]
     },
    
    {
        'kernel':['poly'],'degree':[1,2,3,4],'random_state':[0]
    }
]

param_grid_knn=[

    {   
        'n_neighbors':[1,5,11,15,20,25],
        'p':[2]
        
    }
]

param_grid_nb=[
    {}
]
#RandomF SVC,KNeighborsClassifier, RandomForestClassifier, GradientBoostingClassifier,LogisticRegressio

param_grid_rf=[
               {
                   'n_estimators': np.arange(100, 500, 100),
                  # 'max_depth' : np.arange(5, 100,5)
               }
]

param_grid_xgb=[
               {
                   'n_estimators': np.arange(100,500, 100)
                  
               }
]

param_grid_lr=[
              {}
]

param_grid_array=[param_grid_svm,param_grid_knn,param_grid_rf,param_grid_xgb,param_grid_lr]
multi_grid_search(param_grid_array,model_list,xtrain,ytrain)
# Out:
# {"<class 'sklearn.ensemble._forest.RandomForestClassifier'>": ({'n_estimators': 300},
#   0.9171870928647176),
#  "<class 'sklearn.ensemble._gb.GradientBoostingClassifier'>": ({'n_estimators': 400},
#   0.9004871989092562),
#  "<class 'sklearn.linear_model._logistic.LogisticRegression'>": ({},
#   0.8329901530071201),
#  "<class 'sklearn.neighbors._classification.KNeighborsClassifier'>": ({'n_neighbors': 1,
#    'p': 2},
#   0.9001333131343735),
#  "<class 'sklearn.svm._classes.SVC'>": ({'degree': 1,
#    'kernel': 'poly',
#    'random_state': 0},
#   0.8409931828510832)}

# %%
classifier=RandomForestClassifier(max_depth=25)

# %%
classifier.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
sns.heatmap(pd.crosstab(ytest,classifier.predict(xtest)),cmap='coolwarm')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.show()

# %%
#custom NN
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop,Adam

# %%
print(X.shape)
# Out:
# (4230, 4)

# %%
X_train1, X_test, y_train1, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train1, y_train1, test_size=0.125, random_state=1)

# %%
model=Sequential() 
model.add(Dense(12,activation='relu',input_shape=(3,),kernel_initializer='he_normal'))
# model.add(Dense(45,activation='sigmoid'))
model.add(Dense(20,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dense(5,activation='sigmoid'))
# model.add(Dropout(0.2))
model.add(Dense(15,activation='sigmoid'))
model.add(Dense(5,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dropout(0.2))

# model.add(Dropout(0.2))
# model.add(Dense(90,activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(60,activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(30,activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))
# model.add(DropOut(0.2))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 12)                48
# _________________________________________________________________
# dense_27 (Dense)             (None, 20)                260
# _________________________________________________________________
# dense_28 (Dense)             (None, 15)                315
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 80
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 709
# Trainable params: 709
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(X_train.shape)
# Out:
# (2961, 4)

# %%
model.compile(loss='binary_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy','AUC'])


history = model.fit(X_train1, y_train1,
                    batch_size=32,
                    epochs=250,
                    verbose=1,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/250
# 103/103 [==============================] - 1s 5ms/step - loss: 0.3476 - accuracy: 0.8488 - auc: 0.8951 - val_loss: 0.3386 - val_accuracy: 0.8613 - val_auc: 0.8965
# Epoch 2/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3165 - accuracy: 0.8759 - auc: 0.9077 - val_loss: 0.3515 - val_accuracy: 0.8540 - val_auc: 0.8920
# Epoch 3/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.8624 - auc: 0.8953 - val_loss: 0.3399 - val_accuracy: 0.8613 - val_auc: 0.8965
# Epoch 4/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8623 - auc: 0.9009 - val_loss: 0.3467 - val_accuracy: 0.8589 - val_auc: 0.8898
# Epoch 5/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3199 - accuracy: 0.8685 - auc: 0.9095 - val_loss: 0.3378 - val_accuracy: 0.8564 - val_auc: 0.8986
# Epoch 6/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3381 - accuracy: 0.8644 - auc: 0.8990 - val_loss: 0.3436 - val_accuracy: 0.8467 - val_auc: 0.8909
# Epoch 7/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.8579 - auc: 0.8915 - val_loss: 0.3457 - val_accuracy: 0.8491 - val_auc: 0.8894
# Epoch 8/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.8738 - auc: 0.9112 - val_loss: 0.3411 - val_accuracy: 0.8564 - val_auc: 0.8933
# Epoch 9/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3279 - accuracy: 0.8690 - auc: 0.9030 - val_loss: 0.3407 - val_accuracy: 0.8637 - val_auc: 0.8967
# Epoch 10/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8652 - auc: 0.9038 - val_loss: 0.3445 - val_accuracy: 0.8564 - val_auc: 0.8933
# Epoch 11/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8642 - auc: 0.8992 - val_loss: 0.3390 - val_accuracy: 0.8589 - val_auc: 0.8970
# Epoch 12/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3470 - accuracy: 0.8564 - auc: 0.8984 - val_loss: 0.3498 - val_accuracy: 0.8540 - val_auc: 0.8877
# Epoch 13/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3257 - accuracy: 0.8660 - auc: 0.9017 - val_loss: 0.3445 - val_accuracy: 0.8540 - val_auc: 0.8920
# Epoch 14/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8638 - auc: 0.8946 - val_loss: 0.3412 - val_accuracy: 0.8564 - val_auc: 0.8938
# Epoch 15/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8595 - auc: 0.9012 - val_loss: 0.3399 - val_accuracy: 0.8564 - val_auc: 0.8982
# Epoch 16/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.8574 - auc: 0.8942 - val_loss: 0.3392 - val_accuracy: 0.8540 - val_auc: 0.8970
# Epoch 17/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.8700 - auc: 0.9088 - val_loss: 0.3445 - val_accuracy: 0.8589 - val_auc: 0.8939
# Epoch 18/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3126 - accuracy: 0.8782 - auc: 0.9127 - val_loss: 0.3432 - val_accuracy: 0.8564 - val_auc: 0.8961
# Epoch 19/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3405 - accuracy: 0.8659 - auc: 0.8968 - val_loss: 0.3387 - val_accuracy: 0.8516 - val_auc: 0.8990
# Epoch 20/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8610 - auc: 0.8961 - val_loss: 0.3402 - val_accuracy: 0.8540 - val_auc: 0.8953
# Epoch 21/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8686 - auc: 0.8945 - val_loss: 0.3383 - val_accuracy: 0.8613 - val_auc: 0.8994
# Epoch 22/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3364 - accuracy: 0.8624 - auc: 0.9026 - val_loss: 0.3401 - val_accuracy: 0.8564 - val_auc: 0.8963
# Epoch 23/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3451 - accuracy: 0.8574 - auc: 0.8972 - val_loss: 0.3400 - val_accuracy: 0.8613 - val_auc: 0.8957
# Epoch 24/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8546 - auc: 0.8951 - val_loss: 0.3479 - val_accuracy: 0.8467 - val_auc: 0.8895
# Epoch 25/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8647 - auc: 0.8938 - val_loss: 0.3394 - val_accuracy: 0.8613 - val_auc: 0.8981
# Epoch 26/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3236 - accuracy: 0.8667 - auc: 0.9035 - val_loss: 0.3384 - val_accuracy: 0.8613 - val_auc: 0.8970
# Epoch 27/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.8594 - auc: 0.8946 - val_loss: 0.3449 - val_accuracy: 0.8516 - val_auc: 0.8912
# Epoch 28/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.8657 - auc: 0.9054 - val_loss: 0.3419 - val_accuracy: 0.8516 - val_auc: 0.8952
# Epoch 29/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8581 - auc: 0.8962 - val_loss: 0.3409 - val_accuracy: 0.8516 - val_auc: 0.8937
# Epoch 30/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3279 - accuracy: 0.8682 - auc: 0.9047 - val_loss: 0.3401 - val_accuracy: 0.8564 - val_auc: 0.8959
# Epoch 31/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3294 - accuracy: 0.8635 - auc: 0.8987 - val_loss: 0.3398 - val_accuracy: 0.8564 - val_auc: 0.8954
# Epoch 32/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8633 - auc: 0.9052 - val_loss: 0.3403 - val_accuracy: 0.8613 - val_auc: 0.8940
# Epoch 33/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3459 - accuracy: 0.8617 - auc: 0.8952 - val_loss: 0.3425 - val_accuracy: 0.8540 - val_auc: 0.8916
# Epoch 34/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8614 - auc: 0.9015 - val_loss: 0.3384 - val_accuracy: 0.8589 - val_auc: 0.8991
# Epoch 35/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3152 - accuracy: 0.8744 - auc: 0.9099 - val_loss: 0.3411 - val_accuracy: 0.8540 - val_auc: 0.8924
# Epoch 36/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8531 - auc: 0.8980 - val_loss: 0.3453 - val_accuracy: 0.8637 - val_auc: 0.8938
# Epoch 37/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8578 - auc: 0.9055 - val_loss: 0.3372 - val_accuracy: 0.8613 - val_auc: 0.8983
# Epoch 38/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3290 - accuracy: 0.8665 - auc: 0.9040 - val_loss: 0.3409 - val_accuracy: 0.8467 - val_auc: 0.8948
# Epoch 39/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8542 - auc: 0.9007 - val_loss: 0.3448 - val_accuracy: 0.8516 - val_auc: 0.8915
# Epoch 40/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8622 - auc: 0.9013 - val_loss: 0.3411 - val_accuracy: 0.8564 - val_auc: 0.8958
# Epoch 41/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.8549 - auc: 0.8988 - val_loss: 0.3420 - val_accuracy: 0.8564 - val_auc: 0.8936
# Epoch 42/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3358 - accuracy: 0.8660 - auc: 0.8984 - val_loss: 0.3423 - val_accuracy: 0.8418 - val_auc: 0.8967
# Epoch 43/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8606 - auc: 0.8933 - val_loss: 0.3403 - val_accuracy: 0.8613 - val_auc: 0.8970
# Epoch 44/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3283 - accuracy: 0.8595 - auc: 0.9074 - val_loss: 0.3386 - val_accuracy: 0.8516 - val_auc: 0.8985
# Epoch 45/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8625 - auc: 0.8987 - val_loss: 0.3545 - val_accuracy: 0.8394 - val_auc: 0.8845
# Epoch 46/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8580 - auc: 0.9056 - val_loss: 0.3395 - val_accuracy: 0.8540 - val_auc: 0.8951
# Epoch 47/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8601 - auc: 0.8983 - val_loss: 0.3634 - val_accuracy: 0.8321 - val_auc: 0.8776
# Epoch 48/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3213 - accuracy: 0.8691 - auc: 0.9054 - val_loss: 0.3383 - val_accuracy: 0.8540 - val_auc: 0.8990
# Epoch 49/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8514 - auc: 0.8974 - val_loss: 0.3382 - val_accuracy: 0.8662 - val_auc: 0.8969
# Epoch 50/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3279 - accuracy: 0.8676 - auc: 0.9045 - val_loss: 0.3369 - val_accuracy: 0.8613 - val_auc: 0.8995
# Epoch 51/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8651 - auc: 0.9017 - val_loss: 0.3461 - val_accuracy: 0.8516 - val_auc: 0.8909
# Epoch 52/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8649 - auc: 0.8990 - val_loss: 0.3372 - val_accuracy: 0.8637 - val_auc: 0.8974
# Epoch 53/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8624 - auc: 0.9025 - val_loss: 0.3404 - val_accuracy: 0.8613 - val_auc: 0.8941
# Epoch 54/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8665 - auc: 0.9099 - val_loss: 0.3431 - val_accuracy: 0.8516 - val_auc: 0.8929
# Epoch 55/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8623 - auc: 0.8998 - val_loss: 0.3455 - val_accuracy: 0.8589 - val_auc: 0.8935
# Epoch 56/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.8609 - auc: 0.8912 - val_loss: 0.3396 - val_accuracy: 0.8516 - val_auc: 0.8941
# Epoch 57/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3358 - accuracy: 0.8596 - auc: 0.9058 - val_loss: 0.3375 - val_accuracy: 0.8637 - val_auc: 0.8975
# Epoch 58/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8627 - auc: 0.8992 - val_loss: 0.3403 - val_accuracy: 0.8589 - val_auc: 0.8945
# Epoch 59/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3219 - accuracy: 0.8664 - auc: 0.9092 - val_loss: 0.3406 - val_accuracy: 0.8564 - val_auc: 0.8942
# Epoch 60/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8614 - auc: 0.9023 - val_loss: 0.3412 - val_accuracy: 0.8516 - val_auc: 0.8928
# Epoch 61/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.8769 - auc: 0.9071 - val_loss: 0.3418 - val_accuracy: 0.8467 - val_auc: 0.8936
# Epoch 62/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8537 - auc: 0.9007 - val_loss: 0.3398 - val_accuracy: 0.8564 - val_auc: 0.8984
# Epoch 63/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8565 - auc: 0.9117 - val_loss: 0.3409 - val_accuracy: 0.8516 - val_auc: 0.8928
# Epoch 64/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8608 - auc: 0.8994 - val_loss: 0.3374 - val_accuracy: 0.8637 - val_auc: 0.8979
# Epoch 65/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.8673 - auc: 0.9072 - val_loss: 0.3372 - val_accuracy: 0.8516 - val_auc: 0.8979
# Epoch 66/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.8705 - auc: 0.9083 - val_loss: 0.3406 - val_accuracy: 0.8564 - val_auc: 0.8984
# Epoch 67/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8714 - auc: 0.8968 - val_loss: 0.3404 - val_accuracy: 0.8516 - val_auc: 0.8940
# Epoch 68/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3292 - accuracy: 0.8683 - auc: 0.9026 - val_loss: 0.3363 - val_accuracy: 0.8589 - val_auc: 0.8988
# Epoch 69/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3322 - accuracy: 0.8624 - auc: 0.9021 - val_loss: 0.3386 - val_accuracy: 0.8564 - val_auc: 0.8970
# Epoch 70/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.8690 - auc: 0.9084 - val_loss: 0.3366 - val_accuracy: 0.8613 - val_auc: 0.8977
# Epoch 71/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8668 - auc: 0.9031 - val_loss: 0.3453 - val_accuracy: 0.8540 - val_auc: 0.8916
# Epoch 72/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8543 - auc: 0.8943 - val_loss: 0.3357 - val_accuracy: 0.8637 - val_auc: 0.8991
# Epoch 73/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3232 - accuracy: 0.8696 - auc: 0.9051 - val_loss: 0.3365 - val_accuracy: 0.8637 - val_auc: 0.8994
# Epoch 74/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8596 - auc: 0.8989 - val_loss: 0.3400 - val_accuracy: 0.8613 - val_auc: 0.8963
# Epoch 75/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8680 - auc: 0.9015 - val_loss: 0.3360 - val_accuracy: 0.8613 - val_auc: 0.8984
# Epoch 76/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8618 - auc: 0.9002 - val_loss: 0.3428 - val_accuracy: 0.8491 - val_auc: 0.8917
# Epoch 77/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3289 - accuracy: 0.8679 - auc: 0.8985 - val_loss: 0.3388 - val_accuracy: 0.8564 - val_auc: 0.8973
# Epoch 78/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8651 - auc: 0.8993 - val_loss: 0.3388 - val_accuracy: 0.8564 - val_auc: 0.9013
# Epoch 79/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3254 - accuracy: 0.8635 - auc: 0.9051 - val_loss: 0.3541 - val_accuracy: 0.8540 - val_auc: 0.8934
# Epoch 80/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8606 - auc: 0.9008 - val_loss: 0.3355 - val_accuracy: 0.8613 - val_auc: 0.8988
# Epoch 81/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8534 - auc: 0.8916 - val_loss: 0.3435 - val_accuracy: 0.8564 - val_auc: 0.8926
# Epoch 82/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8542 - auc: 0.8991 - val_loss: 0.3362 - val_accuracy: 0.8589 - val_auc: 0.8975
# Epoch 83/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3405 - accuracy: 0.8664 - auc: 0.8901 - val_loss: 0.3361 - val_accuracy: 0.8589 - val_auc: 0.9002
# Epoch 84/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8672 - auc: 0.8970 - val_loss: 0.3466 - val_accuracy: 0.8467 - val_auc: 0.8933
# Epoch 85/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.8775 - auc: 0.9159 - val_loss: 0.3363 - val_accuracy: 0.8662 - val_auc: 0.9017
# Epoch 86/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8652 - auc: 0.9031 - val_loss: 0.3364 - val_accuracy: 0.8613 - val_auc: 0.8980
# Epoch 87/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3269 - accuracy: 0.8685 - auc: 0.9048 - val_loss: 0.3403 - val_accuracy: 0.8564 - val_auc: 0.8944
# Epoch 88/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8703 - auc: 0.9072 - val_loss: 0.3364 - val_accuracy: 0.8613 - val_auc: 0.8981
# Epoch 89/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3259 - accuracy: 0.8684 - auc: 0.8994 - val_loss: 0.3348 - val_accuracy: 0.8589 - val_auc: 0.9001
# Epoch 90/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8687 - auc: 0.9082 - val_loss: 0.3390 - val_accuracy: 0.8613 - val_auc: 0.8980
# Epoch 91/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3421 - accuracy: 0.8576 - auc: 0.8984 - val_loss: 0.3346 - val_accuracy: 0.8637 - val_auc: 0.9002
# Epoch 92/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8655 - auc: 0.8899 - val_loss: 0.3373 - val_accuracy: 0.8613 - val_auc: 0.8989
# Epoch 93/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3246 - accuracy: 0.8656 - auc: 0.9064 - val_loss: 0.3347 - val_accuracy: 0.8662 - val_auc: 0.8997
# Epoch 94/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3222 - accuracy: 0.8704 - auc: 0.9067 - val_loss: 0.3380 - val_accuracy: 0.8637 - val_auc: 0.8984
# Epoch 95/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8667 - auc: 0.9047 - val_loss: 0.3363 - val_accuracy: 0.8540 - val_auc: 0.9021
# Epoch 96/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.8619 - auc: 0.9080 - val_loss: 0.3361 - val_accuracy: 0.8613 - val_auc: 0.8984
# Epoch 97/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.8651 - auc: 0.9011 - val_loss: 0.3351 - val_accuracy: 0.8589 - val_auc: 0.8988
# Epoch 98/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8626 - auc: 0.9009 - val_loss: 0.3342 - val_accuracy: 0.8564 - val_auc: 0.9034
# Epoch 99/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8628 - auc: 0.9051 - val_loss: 0.3336 - val_accuracy: 0.8516 - val_auc: 0.9040
# Epoch 100/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8670 - auc: 0.8937 - val_loss: 0.3452 - val_accuracy: 0.8589 - val_auc: 0.8933
# Epoch 101/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8652 - auc: 0.9005 - val_loss: 0.3395 - val_accuracy: 0.8564 - val_auc: 0.8966
# Epoch 102/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8693 - auc: 0.9018 - val_loss: 0.3494 - val_accuracy: 0.8443 - val_auc: 0.8877
# Epoch 103/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8603 - auc: 0.9000 - val_loss: 0.3386 - val_accuracy: 0.8491 - val_auc: 0.8979
# Epoch 104/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8615 - auc: 0.8956 - val_loss: 0.3374 - val_accuracy: 0.8589 - val_auc: 0.9018
# Epoch 105/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8704 - auc: 0.9132 - val_loss: 0.3363 - val_accuracy: 0.8613 - val_auc: 0.8975
# Epoch 106/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3119 - accuracy: 0.8732 - auc: 0.9119 - val_loss: 0.3452 - val_accuracy: 0.8662 - val_auc: 0.8950
# Epoch 107/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8553 - auc: 0.8936 - val_loss: 0.3356 - val_accuracy: 0.8637 - val_auc: 0.8987
# Epoch 108/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8586 - auc: 0.8966 - val_loss: 0.3382 - val_accuracy: 0.8564 - val_auc: 0.8984
# Epoch 109/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.8678 - auc: 0.9020 - val_loss: 0.3409 - val_accuracy: 0.8589 - val_auc: 0.8953
# Epoch 110/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8590 - auc: 0.8990 - val_loss: 0.3448 - val_accuracy: 0.8467 - val_auc: 0.8945
# Epoch 111/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3210 - accuracy: 0.8747 - auc: 0.9100 - val_loss: 0.3441 - val_accuracy: 0.8686 - val_auc: 0.8970
# Epoch 112/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8582 - auc: 0.8985 - val_loss: 0.3511 - val_accuracy: 0.8394 - val_auc: 0.8865
# Epoch 113/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3222 - accuracy: 0.8723 - auc: 0.9068 - val_loss: 0.3358 - val_accuracy: 0.8564 - val_auc: 0.9049
# Epoch 114/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8654 - auc: 0.9033 - val_loss: 0.3346 - val_accuracy: 0.8613 - val_auc: 0.9002
# Epoch 115/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3264 - accuracy: 0.8726 - auc: 0.9024 - val_loss: 0.3403 - val_accuracy: 0.8540 - val_auc: 0.8951
# Epoch 116/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8650 - auc: 0.9026 - val_loss: 0.3367 - val_accuracy: 0.8589 - val_auc: 0.8989
# Epoch 117/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8690 - auc: 0.8989 - val_loss: 0.3345 - val_accuracy: 0.8637 - val_auc: 0.9000
# Epoch 118/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8580 - auc: 0.8988 - val_loss: 0.3357 - val_accuracy: 0.8589 - val_auc: 0.9008
# Epoch 119/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8685 - auc: 0.9032 - val_loss: 0.3341 - val_accuracy: 0.8589 - val_auc: 0.9021
# Epoch 120/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8647 - auc: 0.9015 - val_loss: 0.3355 - val_accuracy: 0.8637 - val_auc: 0.8974
# Epoch 121/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8576 - auc: 0.8937 - val_loss: 0.3338 - val_accuracy: 0.8516 - val_auc: 0.9040
# Epoch 122/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8687 - auc: 0.9027 - val_loss: 0.3363 - val_accuracy: 0.8589 - val_auc: 0.8968
# Epoch 123/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3278 - accuracy: 0.8620 - auc: 0.9051 - val_loss: 0.3332 - val_accuracy: 0.8637 - val_auc: 0.9011
# Epoch 124/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8581 - auc: 0.8955 - val_loss: 0.3373 - val_accuracy: 0.8589 - val_auc: 0.8965
# Epoch 125/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3116 - accuracy: 0.8721 - auc: 0.9186 - val_loss: 0.3375 - val_accuracy: 0.8564 - val_auc: 0.8961
# Epoch 126/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.8680 - auc: 0.9111 - val_loss: 0.3409 - val_accuracy: 0.8491 - val_auc: 0.8943
# Epoch 127/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3522 - accuracy: 0.8505 - auc: 0.8936 - val_loss: 0.3386 - val_accuracy: 0.8613 - val_auc: 0.8933
# Epoch 128/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3317 - accuracy: 0.8640 - auc: 0.9022 - val_loss: 0.3362 - val_accuracy: 0.8589 - val_auc: 0.8983
# Epoch 129/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3280 - accuracy: 0.8591 - auc: 0.9099 - val_loss: 0.3356 - val_accuracy: 0.8564 - val_auc: 0.8994
# Epoch 130/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8575 - auc: 0.8903 - val_loss: 0.3369 - val_accuracy: 0.8589 - val_auc: 0.8993
# Epoch 131/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3183 - accuracy: 0.8695 - auc: 0.9125 - val_loss: 0.3345 - val_accuracy: 0.8516 - val_auc: 0.9025
# Epoch 132/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3238 - accuracy: 0.8633 - auc: 0.9083 - val_loss: 0.3336 - val_accuracy: 0.8637 - val_auc: 0.9019
# Epoch 133/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.8653 - auc: 0.9101 - val_loss: 0.3391 - val_accuracy: 0.8637 - val_auc: 0.8967
# Epoch 134/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3196 - accuracy: 0.8707 - auc: 0.9076 - val_loss: 0.3390 - val_accuracy: 0.8637 - val_auc: 0.9026
# Epoch 135/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3105 - accuracy: 0.8781 - auc: 0.9141 - val_loss: 0.3343 - val_accuracy: 0.8613 - val_auc: 0.9032
# Epoch 136/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8636 - auc: 0.9005 - val_loss: 0.3366 - val_accuracy: 0.8589 - val_auc: 0.8988
# Epoch 137/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3234 - accuracy: 0.8704 - auc: 0.9080 - val_loss: 0.3327 - val_accuracy: 0.8589 - val_auc: 0.9059
# Epoch 138/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.8723 - auc: 0.9026 - val_loss: 0.3357 - val_accuracy: 0.8589 - val_auc: 0.9022
# Epoch 139/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3514 - accuracy: 0.8560 - auc: 0.8925 - val_loss: 0.3440 - val_accuracy: 0.8564 - val_auc: 0.8905
# Epoch 140/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8640 - auc: 0.9022 - val_loss: 0.3354 - val_accuracy: 0.8637 - val_auc: 0.8966
# Epoch 141/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.8693 - auc: 0.9097 - val_loss: 0.3344 - val_accuracy: 0.8613 - val_auc: 0.9004
# Epoch 142/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 0.8691 - auc: 0.9112 - val_loss: 0.3440 - val_accuracy: 0.8516 - val_auc: 0.8920
# Epoch 143/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8498 - auc: 0.8847 - val_loss: 0.3403 - val_accuracy: 0.8540 - val_auc: 0.9005
# Epoch 144/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3350 - accuracy: 0.8567 - auc: 0.9063 - val_loss: 0.3341 - val_accuracy: 0.8613 - val_auc: 0.9008
# Epoch 145/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8741 - auc: 0.9081 - val_loss: 0.3338 - val_accuracy: 0.8589 - val_auc: 0.8999
# Epoch 146/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3308 - accuracy: 0.8667 - auc: 0.9072 - val_loss: 0.3426 - val_accuracy: 0.8564 - val_auc: 0.8948
# Epoch 147/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8624 - auc: 0.9051 - val_loss: 0.3371 - val_accuracy: 0.8589 - val_auc: 0.8989
# Epoch 148/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8624 - auc: 0.9052 - val_loss: 0.3334 - val_accuracy: 0.8589 - val_auc: 0.9034
# Epoch 149/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.8711 - auc: 0.9150 - val_loss: 0.3418 - val_accuracy: 0.8540 - val_auc: 0.8915
# Epoch 150/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8617 - auc: 0.9011 - val_loss: 0.3344 - val_accuracy: 0.8564 - val_auc: 0.9049
# Epoch 151/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.8647 - auc: 0.9055 - val_loss: 0.3361 - val_accuracy: 0.8613 - val_auc: 0.8995
# Epoch 152/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3081 - accuracy: 0.8724 - auc: 0.9189 - val_loss: 0.3366 - val_accuracy: 0.8540 - val_auc: 0.9015
# Epoch 153/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3141 - accuracy: 0.8729 - auc: 0.9148 - val_loss: 0.3496 - val_accuracy: 0.8370 - val_auc: 0.8931
# Epoch 154/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8660 - auc: 0.9012 - val_loss: 0.3350 - val_accuracy: 0.8613 - val_auc: 0.9033
# Epoch 155/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3322 - accuracy: 0.8630 - auc: 0.8998 - val_loss: 0.3338 - val_accuracy: 0.8613 - val_auc: 0.9025
# Epoch 156/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3231 - accuracy: 0.8696 - auc: 0.9057 - val_loss: 0.3375 - val_accuracy: 0.8589 - val_auc: 0.9021
# Epoch 157/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3232 - accuracy: 0.8706 - auc: 0.9052 - val_loss: 0.3353 - val_accuracy: 0.8589 - val_auc: 0.8983
# Epoch 158/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3209 - accuracy: 0.8702 - auc: 0.9065 - val_loss: 0.3340 - val_accuracy: 0.8589 - val_auc: 0.8996
# Epoch 159/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3292 - accuracy: 0.8672 - auc: 0.8988 - val_loss: 0.3330 - val_accuracy: 0.8613 - val_auc: 0.9000
# Epoch 160/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8597 - auc: 0.9016 - val_loss: 0.3351 - val_accuracy: 0.8589 - val_auc: 0.9036
# Epoch 161/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8660 - auc: 0.9063 - val_loss: 0.3549 - val_accuracy: 0.8321 - val_auc: 0.8856
# Epoch 162/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3410 - accuracy: 0.8624 - auc: 0.8940 - val_loss: 0.3373 - val_accuracy: 0.8589 - val_auc: 0.8967
# Epoch 163/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8707 - auc: 0.9064 - val_loss: 0.3330 - val_accuracy: 0.8637 - val_auc: 0.9050
# Epoch 164/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3183 - accuracy: 0.8680 - auc: 0.9112 - val_loss: 0.3335 - val_accuracy: 0.8637 - val_auc: 0.9025
# Epoch 165/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8676 - auc: 0.9038 - val_loss: 0.3319 - val_accuracy: 0.8662 - val_auc: 0.9008
# Epoch 166/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3503 - accuracy: 0.8591 - auc: 0.8969 - val_loss: 0.3405 - val_accuracy: 0.8589 - val_auc: 0.8975
# Epoch 167/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3227 - accuracy: 0.8699 - auc: 0.9077 - val_loss: 0.3435 - val_accuracy: 0.8540 - val_auc: 0.8929
# Epoch 168/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8681 - auc: 0.9039 - val_loss: 0.3331 - val_accuracy: 0.8613 - val_auc: 0.9022
# Epoch 169/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3275 - accuracy: 0.8646 - auc: 0.9072 - val_loss: 0.3379 - val_accuracy: 0.8540 - val_auc: 0.8989
# Epoch 170/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3247 - accuracy: 0.8707 - auc: 0.9077 - val_loss: 0.3339 - val_accuracy: 0.8564 - val_auc: 0.9034
# Epoch 171/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8642 - auc: 0.9028 - val_loss: 0.3336 - val_accuracy: 0.8613 - val_auc: 0.9036
# Epoch 172/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.8680 - auc: 0.9044 - val_loss: 0.3383 - val_accuracy: 0.8564 - val_auc: 0.8997
# Epoch 173/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3278 - accuracy: 0.8652 - auc: 0.9020 - val_loss: 0.3335 - val_accuracy: 0.8589 - val_auc: 0.9009
# Epoch 174/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.8722 - auc: 0.9117 - val_loss: 0.3430 - val_accuracy: 0.8467 - val_auc: 0.8963
# Epoch 175/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8675 - auc: 0.9069 - val_loss: 0.3339 - val_accuracy: 0.8589 - val_auc: 0.9035
# Epoch 176/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3335 - accuracy: 0.8632 - auc: 0.9049 - val_loss: 0.3352 - val_accuracy: 0.8637 - val_auc: 0.9014
# Epoch 177/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8647 - auc: 0.8985 - val_loss: 0.3392 - val_accuracy: 0.8443 - val_auc: 0.8990
# Epoch 178/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3188 - accuracy: 0.8681 - auc: 0.9085 - val_loss: 0.3347 - val_accuracy: 0.8589 - val_auc: 0.9056
# Epoch 179/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8639 - auc: 0.9014 - val_loss: 0.3352 - val_accuracy: 0.8589 - val_auc: 0.9006
# Epoch 180/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3218 - accuracy: 0.8651 - auc: 0.9092 - val_loss: 0.3416 - val_accuracy: 0.8516 - val_auc: 0.8933
# Epoch 181/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3032 - accuracy: 0.8820 - auc: 0.9134 - val_loss: 0.3320 - val_accuracy: 0.8613 - val_auc: 0.9051
# Epoch 182/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3228 - accuracy: 0.8687 - auc: 0.9100 - val_loss: 0.3335 - val_accuracy: 0.8589 - val_auc: 0.9028
# Epoch 183/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8539 - auc: 0.8980 - val_loss: 0.3310 - val_accuracy: 0.8637 - val_auc: 0.9049
# Epoch 184/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8633 - auc: 0.8978 - val_loss: 0.3324 - val_accuracy: 0.8613 - val_auc: 0.9016
# Epoch 185/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.8730 - auc: 0.9115 - val_loss: 0.3336 - val_accuracy: 0.8637 - val_auc: 0.9020
# Epoch 186/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.8609 - auc: 0.9055 - val_loss: 0.3424 - val_accuracy: 0.8613 - val_auc: 0.9037
# Epoch 187/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.8730 - auc: 0.9138 - val_loss: 0.3305 - val_accuracy: 0.8637 - val_auc: 0.9054
# Epoch 188/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.8656 - auc: 0.9027 - val_loss: 0.3385 - val_accuracy: 0.8540 - val_auc: 0.8967
# Epoch 189/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3218 - accuracy: 0.8699 - auc: 0.9064 - val_loss: 0.3324 - val_accuracy: 0.8589 - val_auc: 0.9046
# Epoch 190/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8640 - auc: 0.9050 - val_loss: 0.3331 - val_accuracy: 0.8637 - val_auc: 0.9078
# Epoch 191/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3322 - accuracy: 0.8605 - auc: 0.9029 - val_loss: 0.3335 - val_accuracy: 0.8613 - val_auc: 0.8997
# Epoch 192/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3006 - accuracy: 0.8817 - auc: 0.9197 - val_loss: 0.3297 - val_accuracy: 0.8686 - val_auc: 0.9047
# Epoch 193/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.8635 - auc: 0.8993 - val_loss: 0.3316 - val_accuracy: 0.8662 - val_auc: 0.9012
# Epoch 194/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3247 - accuracy: 0.8713 - auc: 0.9096 - val_loss: 0.3316 - val_accuracy: 0.8613 - val_auc: 0.9040
# Epoch 195/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8702 - auc: 0.9066 - val_loss: 0.3346 - val_accuracy: 0.8564 - val_auc: 0.8999
# Epoch 196/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8631 - auc: 0.9015 - val_loss: 0.3351 - val_accuracy: 0.8613 - val_auc: 0.9006
# Epoch 197/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.8591 - auc: 0.8994 - val_loss: 0.3326 - val_accuracy: 0.8516 - val_auc: 0.9078
# Epoch 198/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8590 - auc: 0.8935 - val_loss: 0.3404 - val_accuracy: 0.8491 - val_auc: 0.8954
# Epoch 199/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3444 - accuracy: 0.8558 - auc: 0.8968 - val_loss: 0.3308 - val_accuracy: 0.8637 - val_auc: 0.9033
# Epoch 200/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8567 - auc: 0.9041 - val_loss: 0.3306 - val_accuracy: 0.8589 - val_auc: 0.9021
# Epoch 201/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3246 - accuracy: 0.8728 - auc: 0.9105 - val_loss: 0.3308 - val_accuracy: 0.8589 - val_auc: 0.9081
# Epoch 202/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3303 - accuracy: 0.8687 - auc: 0.9034 - val_loss: 0.3425 - val_accuracy: 0.8564 - val_auc: 0.8953
# Epoch 203/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3169 - accuracy: 0.8678 - auc: 0.9105 - val_loss: 0.3318 - val_accuracy: 0.8613 - val_auc: 0.9056
# Epoch 204/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8618 - auc: 0.9046 - val_loss: 0.3403 - val_accuracy: 0.8564 - val_auc: 0.8950
# Epoch 205/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3060 - accuracy: 0.8734 - auc: 0.9213 - val_loss: 0.3310 - val_accuracy: 0.8686 - val_auc: 0.9087
# Epoch 206/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8690 - auc: 0.9071 - val_loss: 0.3313 - val_accuracy: 0.8589 - val_auc: 0.9043
# Epoch 207/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8619 - auc: 0.9039 - val_loss: 0.3302 - val_accuracy: 0.8613 - val_auc: 0.9084
# Epoch 208/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8646 - auc: 0.9014 - val_loss: 0.3337 - val_accuracy: 0.8540 - val_auc: 0.9056
# Epoch 209/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.8716 - auc: 0.9109 - val_loss: 0.3384 - val_accuracy: 0.8686 - val_auc: 0.8974
# Epoch 210/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8664 - auc: 0.8977 - val_loss: 0.3302 - val_accuracy: 0.8637 - val_auc: 0.9038
# Epoch 211/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8630 - auc: 0.9038 - val_loss: 0.3304 - val_accuracy: 0.8662 - val_auc: 0.9079
# Epoch 212/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3239 - accuracy: 0.8705 - auc: 0.9048 - val_loss: 0.3307 - val_accuracy: 0.8613 - val_auc: 0.9035
# Epoch 213/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8734 - auc: 0.9089 - val_loss: 0.3367 - val_accuracy: 0.8589 - val_auc: 0.8985
# Epoch 214/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3212 - accuracy: 0.8719 - auc: 0.9089 - val_loss: 0.3365 - val_accuracy: 0.8613 - val_auc: 0.9011
# Epoch 215/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.8686 - auc: 0.9073 - val_loss: 0.3297 - val_accuracy: 0.8613 - val_auc: 0.9064
# Epoch 216/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.8684 - auc: 0.9058 - val_loss: 0.3314 - val_accuracy: 0.8613 - val_auc: 0.9021
# Epoch 217/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8678 - auc: 0.9057 - val_loss: 0.3342 - val_accuracy: 0.8613 - val_auc: 0.9008
# Epoch 218/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8624 - auc: 0.9033 - val_loss: 0.3351 - val_accuracy: 0.8613 - val_auc: 0.9058
# Epoch 219/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.8505 - auc: 0.8966 - val_loss: 0.3359 - val_accuracy: 0.8662 - val_auc: 0.8961
# Epoch 220/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8563 - auc: 0.8974 - val_loss: 0.3344 - val_accuracy: 0.8564 - val_auc: 0.8981
# Epoch 221/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8554 - auc: 0.8980 - val_loss: 0.3307 - val_accuracy: 0.8637 - val_auc: 0.9041
# Epoch 222/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8705 - auc: 0.9087 - val_loss: 0.3303 - val_accuracy: 0.8637 - val_auc: 0.9089
# Epoch 223/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3219 - accuracy: 0.8757 - auc: 0.9080 - val_loss: 0.3301 - val_accuracy: 0.8589 - val_auc: 0.9035
# Epoch 224/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8643 - auc: 0.9133 - val_loss: 0.3394 - val_accuracy: 0.8540 - val_auc: 0.8939
# Epoch 225/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8586 - auc: 0.9010 - val_loss: 0.3300 - val_accuracy: 0.8613 - val_auc: 0.9025
# Epoch 226/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8639 - auc: 0.9009 - val_loss: 0.3330 - val_accuracy: 0.8637 - val_auc: 0.9022
# Epoch 227/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3253 - accuracy: 0.8666 - auc: 0.9015 - val_loss: 0.3300 - val_accuracy: 0.8686 - val_auc: 0.9068
# Epoch 228/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3149 - accuracy: 0.8754 - auc: 0.9105 - val_loss: 0.3318 - val_accuracy: 0.8589 - val_auc: 0.9077
# Epoch 229/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8655 - auc: 0.9071 - val_loss: 0.3323 - val_accuracy: 0.8613 - val_auc: 0.9050
# Epoch 230/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8645 - auc: 0.9060 - val_loss: 0.3296 - val_accuracy: 0.8589 - val_auc: 0.9102
# Epoch 231/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.8512 - auc: 0.8942 - val_loss: 0.3307 - val_accuracy: 0.8613 - val_auc: 0.9049
# Epoch 232/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3213 - accuracy: 0.8690 - auc: 0.9087 - val_loss: 0.3277 - val_accuracy: 0.8686 - val_auc: 0.9088
# Epoch 233/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8600 - auc: 0.9021 - val_loss: 0.3307 - val_accuracy: 0.8686 - val_auc: 0.9082
# Epoch 234/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.8664 - auc: 0.9048 - val_loss: 0.3357 - val_accuracy: 0.8589 - val_auc: 0.9017
# Epoch 235/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8712 - auc: 0.9079 - val_loss: 0.3289 - val_accuracy: 0.8710 - val_auc: 0.9121
# Epoch 236/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8628 - auc: 0.9132 - val_loss: 0.3280 - val_accuracy: 0.8662 - val_auc: 0.9083
# Epoch 237/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3237 - accuracy: 0.8681 - auc: 0.9072 - val_loss: 0.3407 - val_accuracy: 0.8564 - val_auc: 0.8967
# Epoch 238/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3297 - accuracy: 0.8715 - auc: 0.9071 - val_loss: 0.3306 - val_accuracy: 0.8662 - val_auc: 0.9042
# Epoch 239/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8649 - auc: 0.9048 - val_loss: 0.3298 - val_accuracy: 0.8589 - val_auc: 0.9089
# Epoch 240/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8678 - auc: 0.9096 - val_loss: 0.3293 - val_accuracy: 0.8637 - val_auc: 0.9104
# Epoch 241/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3205 - accuracy: 0.8681 - auc: 0.9115 - val_loss: 0.3340 - val_accuracy: 0.8589 - val_auc: 0.9016
# Epoch 242/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8518 - auc: 0.9047 - val_loss: 0.3343 - val_accuracy: 0.8589 - val_auc: 0.9019
# Epoch 243/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.8623 - auc: 0.9078 - val_loss: 0.3328 - val_accuracy: 0.8443 - val_auc: 0.9078
# Epoch 244/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3209 - accuracy: 0.8748 - auc: 0.9083 - val_loss: 0.3316 - val_accuracy: 0.8637 - val_auc: 0.9091
# Epoch 245/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3216 - accuracy: 0.8741 - auc: 0.9085 - val_loss: 0.3314 - val_accuracy: 0.8589 - val_auc: 0.9071
# Epoch 246/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8581 - auc: 0.8987 - val_loss: 0.3287 - val_accuracy: 0.8613 - val_auc: 0.9084
# Epoch 247/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.8613 - auc: 0.9009 - val_loss: 0.3351 - val_accuracy: 0.8589 - val_auc: 0.8977
# Epoch 248/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3174 - accuracy: 0.8711 - auc: 0.9096 - val_loss: 0.3320 - val_accuracy: 0.8686 - val_auc: 0.9053
# Epoch 249/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.8761 - auc: 0.9158 - val_loss: 0.3276 - val_accuracy: 0.8686 - val_auc: 0.9118
# Epoch 250/250
# 103/103 [==============================] - 0s 2ms/step - loss: 0.3433 - accuracy: 0.8540 - auc: 0.8995 - val_loss: 0.3317 - val_accuracy: 0.8589 - val_auc: 0.9045

# %%
score = model.evaluate(X_test,y_test, verbose=0)
print(score)
print('Test accuracy:', score[1])
# Out:
# [0.3238428831100464, 0.8686131238937378, 0.8990457057952881]
# Test accuracy: 0.8686131238937378

# %%
model.save('geoemtry_wo_height.h5')

# %%
# !ls
# Out:
#  409_2020_Assignment_1.pdf	      multimodal1.h5
#  ad.data			      multi_modal_1.png
#  ad.DOCUMENTATION		      multiModal_1.png
#  ad.names			      multi_modal_2.png
#  ad.txt				      multiModal_2.png
#  Assignment_2			      multimodelmachax_1
#  augmented			      multimodelmachax_1.h5
#  augmented.txt			      multimodelmachax_2.h5
#  auto_model			      multimodelmachax_3.h5
#  C4.5				      multimodelmachax_40.h5
# 'Colab Notebooks'		      multimodelmachax_41.h5
#  column_names.csv		      multimodelmachax_4.h5
#  complete_data.csv		      nlp_score_3279.csv
# 'Copy of data.csv'		      nlp_score_synth.csv
#  crawl-300d-2M.vec.zip		     'ntj-nzse-rum - Mar 28, 2021.gjam'
#  data.csv			      os_lectures-20210308T033926Z-001.zip
#  Dataset			      os_lectures-20210308T033926Z-002.zip
#  data_without_outliers.csv	      outputs
#  DeepLearning.mp4		      pca_data.csv
#  dfffff.csv			      Q2.ipynb
#  discdatacomp_100.csv		      Q3.ipynb
#  discdatacomp_2000.csv		      RPData.csv
#  discdatacomp.csv		      Shap_data.csv
#  ELL409				      shap_naive_disc.csv
#  geoemtry.h5			      shapNN1.h5
#  geoemtry_wo_height.h5		      shapNN2.h5
# 'ihy-waii-fvi - Mar 8, 2021.gjam'     shapNN4.h5
# 'IMAGES AND SOURCES'		      shapNN5.h5
#  llll.h5			      short_synth.csv
#  Medical_MNIST.zip		      Synthetic_data.csv
#  model_weights_Skewed_2.h5	      Synthetic_data_final.csv
#  multi_input_and_output_model_4.png  'Untitled document.gdoc'
#  multi_input_and_output_model_5.png   ver2.2.h5
#  multi_input_and_output_model7.png    wacomTablet
#  multi_input_and_output_model.png     weather_data.xlsx
