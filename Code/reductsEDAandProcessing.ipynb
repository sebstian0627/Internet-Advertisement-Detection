# %%
s = "65         173         533        1230          442        1044         870         242        1007        1059         187        1023          35         810         407        1538          33         171         283        1530         168         196         470          40         200         214          53        1053        1088          28          36          48         178         113         983          44          91        1480          51          96         951        1248        1537         227         298         500        1345           1         999         885         236           2        3           4        1466         188        1279         549         352        1400         299        1471         521          61         121        1398        1455         861       458          68         583        1463         167         285         204         507        969        1229"

# %%
import pandas as pd
import numpy as np
import os

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive'

# %%
pos = s.split();
pos.append('1559')
for i in range(len(pos)):
  pos[i] = int(pos[i])
pos_sorted = sorted(pos)

# %%
len(pos_sorted)
# Out:
# 79

# %%
df = pd.read_csv("Synthetic_data.csv")

# %%
# dict_n = pd.DataFrame.to_dict(df, orient = "records")

# %%
#dict_n

# %%
heads = df.columns.to_list()
heads

# %%
reducts = list()
for i in range(len(pos)):
  curr = int(pos_sorted[i]) - 1
  reducts.append(heads[curr])
# reducts

# %%
apple = df[reducts]
# apple.describe()

# %%
apple.to_csv("reducts_data", index = False)

# %%
df = apple

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import collections
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import  cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier


# %matplotlib inline
import os

# %%
columns_for_visualization = list()
for i in range(78):
  columns_for_visualization.append(reducts[i])
corr=df[columns_for_visualization].corr()
fig, ax = plt.subplots(figsize=(50,50))
sns.heatmap(corr,annot=True,linewidths=.5, ax=ax)

# %%
da=df.values
X=da[:,:-1]
y=da[:,-1]


xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.30,random_state=80)

# %%
def fit_models(classifiers,xtrain,ytrain):
    """This function fit multiple models by sklearn and return the dictionary with values as  objects of models"""
    models=collections.OrderedDict()
    for constructor in classifiers:
        obj=constructor()
        obj.fit(xtrain,ytrain)
        models[str(constructor).split(':')[0]]=obj
    return models

def classification_multi_report(ytest,models_array):
    """This function generate classification accuracy report for given input model objects"""
    for i in models_array:
        print('__________________________________________________')
        print('the model - '+str(i))
        print(classification_report(ytest,models_array[i].predict(xtest)))
def cross_Function(models,cv):
    """This function return cross validated accuray and the variance of given input model obejects"""
    accuracy={}
    for model in models:
        cross_val_array=cross_val_score(models[model],xtrain,ytrain,scoring='accuracy',cv=cv)
        accuracy[model]=[np.mean(cross_val_array),np.std(cross_val_array)]
    return accuracy

def multi_grid_search(param_grid_array,estimator_list,x,y):
    """This function calculate the grid search parameters and accuracy  for given input modles and return dictionary with each tupple containing accuracy and best parameters"""
    d={}
    count=0
    for i in estimator_list:
        gc=GridSearchCV(estimator=estimator_list[i],param_grid=param_grid_array[count],scoring ='accuracy',cv=5).fit(x,y)
        d[i]=(gc.best_params_,gc.best_score_)
        count+=1
    return d

# %%
classifiers=[SVC, KNeighborsClassifier, RandomForestClassifier, XGBClassifier, DecisionTreeClassifier, LogisticRegression]

# classifiers=[GaussianNB,SVC,KNeighborsClassifier]

model_list=fit_models(classifiers,xtrain,ytrain)

classification_multi_report(ytest,model_list)
# Out:
# __________________________________________________
# the model - <class 'sklearn.svm._classes.SVC'>
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       419
#          1.0       0.96      0.99      0.97       850
#
#     accuracy                           0.96      1269
#    macro avg       0.97      0.95      0.96      1269
# weighted avg       0.96      0.96      0.96      1269
#
# __________________________________________________
# the model - <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       419
#          1.0       0.97      0.98      0.98       850
#
#     accuracy                           0.97      1269
#    macro avg       0.97      0.96      0.97      1269
# weighted avg       0.97      0.97      0.97      1269
#
# __________________________________________________
# the model - <class 'sklearn.ensemble._forest.RandomForestClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.96       419
#          1.0       0.97      0.99      0.98       850
#
#     accuracy                           0.98      1269
#    macro avg       0.98      0.97      0.97      1269
# weighted avg       0.98      0.98      0.98      1269
#
# __________________________________________________
# the model - <class 'xgboost.sklearn.XGBClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.92       419
#          1.0       0.94      0.99      0.97       850
#
#     accuracy                           0.95      1269
#    macro avg       0.96      0.93      0.94      1269
# weighted avg       0.95      0.95      0.95      1269
#
# __________________________________________________
# the model - <class 'sklearn.tree._classes.DecisionTreeClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95       419
#          1.0       0.97      0.98      0.98       850
#
#     accuracy                           0.97      1269
#    macro avg       0.97      0.96      0.96      1269
# weighted avg       0.97      0.97      0.97      1269
#
# __________________________________________________
# the model - <class 'sklearn.linear_model._logistic.LogisticRegression'>
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.85      0.91       419
#          1.0       0.93      0.99      0.96       850
#
#     accuracy                           0.94      1269
#    macro avg       0.95      0.92      0.93      1269
# weighted avg       0.94      0.94      0.94      1269

# %%
obj=cross_Function(model_list,cv=20)
for model in obj:
    print('the model -'+str(model)+'has \n || crosss validated accuracy as  -> '+str(obj[model][0])+' | variance - '+str(obj[model][1])+' ||' )
    print('______________________________________________________________________________________________________________')
# Out:
# the model -<class 'sklearn.svm._classes.SVC'>has
#  || crosss validated accuracy as  -> 0.9486028568449587 | variance - 0.017137616914820825 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.neighbors._classification.KNeighborsClassifier'>has
#  || crosss validated accuracy as  -> 0.961273589823793 | variance - 0.01638786756881101 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.ensemble._forest.RandomForestClassifier'>has
#  || crosss validated accuracy as  -> 0.9703185277864665 | variance - 0.016823728659688383 ||
# ______________________________________________________________________________________________________________
# the model -<class 'xgboost.sklearn.XGBClassifier'>has
#  || crosss validated accuracy as  -> 0.9467990824731517 | variance - 0.01655037482292594 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.tree._classes.DecisionTreeClassifier'>has
#  || crosss validated accuracy as  -> 0.9496976331977898 | variance - 0.015592035535213766 ||
# ______________________________________________________________________________________________________________

# %%
param_grid_svm=[
    {
        'kernel':['linear'],'random_state':[0]
    },
     {
        'kernel':['rbf'],'random_state':[0]
     },
    
    {
        'kernel':['poly'],'degree':[1,2,3,4],'random_state':[0]
    }
]

param_grid_knn=[

    {   
        'n_neighbors':np.arange(1,3),
        'p':[2]
        
    }
]

param_RandomForest = [
    {
        'n_estimators': np.arange(100, 500, 50),
        'max_depth' : np.arange(5, 35, 5)
    }
]

param_XGB=[
    {
        'n_estimators' : np.arange(100, 500, 100)
    }
]

param_dc = [
  {
      
  }
]

param_XGBoost=[
    {
        'n_estimators' : np.arange(100, 500, 100),
        # 'max_depth' : np.arange(5, 30, 5)
    }
]

param_grid_array=[param_grid_svm, param_grid_knn, param_RandomForest, param_XGBoost, param_dc]
multi_grid_search(param_grid_array,model_list,xtrain,ytrain)
# Out:
# {"<class 'sklearn.ensemble._forest.RandomForestClassifier'>": ({'max_depth': 30,
#    'n_estimators': 200},
#   0.9681532877322641),
#  "<class 'sklearn.neighbors._classification.KNeighborsClassifier'>": ({'n_neighbors': 1,
#    'p': 2},
#   0.9667027019943916),
#  "<class 'sklearn.svm._classes.SVC'>": ({'degree': 4,
#    'kernel': 'poly',
#    'random_state': 0},
#   0.951505621511125),
#  "<class 'sklearn.tree._classes.DecisionTreeClassifier'>": ({},
#   0.9547664910763425),
#  "<class 'xgboost.sklearn.XGBClassifier'>": ({'n_estimators': 400},
#   0.965620986974867)}

# %%
#Neural Net Models
#custom NN
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop,Adam
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("reducts_data")

# %%
da=df.values
X=da[:,:-1]
y=da[:,-1]

# %%
X_train1, X_test, y_train1, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train1, y_train1, test_size=0.125, random_state=1)

# %%
#model params
model=Sequential()
model.add(Dense(30, input_dim=X_train.shape[1], activation='relu', kernel_initializer='he_normal'))
# model.add(Dense(200,activation='sigmoid',input_shape=(15,)))
# model.add(Dropout(0.2))
# model.add(Dense(300,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dense(200,activation='sigmoid'))
# model.add(Dense(100,activation='sigmoid'))
model.add(Dense(25,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dense(20,activation='sigmoid'))
model.add(Dense(30,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10,activation='sigmoid'))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 30)                2370
# _________________________________________________________________
# dense_31 (Dense)             (None, 25)                775
# _________________________________________________________________
# dense_32 (Dense)             (None, 30)                780
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 3,956
# Trainable params: 3,956
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy','AUC'])

# class_weights={0: 1,
#                 1:2.5,
#                 2: 5}
history = model.fit(X_train1, y_train1, batch_size=64, epochs=50, verbose=1, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 8ms/step - loss: 0.0752 - accuracy: 0.9758 - auc: 0.9943 - val_loss: 0.0800 - val_accuracy: 0.9772 - val_auc: 0.9929
# Epoch 2/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9765 - auc: 0.9957 - val_loss: 0.0810 - val_accuracy: 0.9772 - val_auc: 0.9931
# Epoch 3/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 0.9793 - auc: 0.9955 - val_loss: 0.0799 - val_accuracy: 0.9747 - val_auc: 0.9933
# Epoch 4/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9778 - auc: 0.9951 - val_loss: 0.0781 - val_accuracy: 0.9772 - val_auc: 0.9933
# Epoch 5/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9796 - auc: 0.9946 - val_loss: 0.0793 - val_accuracy: 0.9772 - val_auc: 0.9929
# Epoch 6/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0622 - accuracy: 0.9797 - auc: 0.9956 - val_loss: 0.0790 - val_accuracy: 0.9747 - val_auc: 0.9929
# Epoch 7/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 0.9831 - auc: 0.9964 - val_loss: 0.0838 - val_accuracy: 0.9772 - val_auc: 0.9928
# Epoch 8/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9765 - auc: 0.9954 - val_loss: 0.0807 - val_accuracy: 0.9772 - val_auc: 0.9929
# Epoch 9/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 0.9848 - auc: 0.9962 - val_loss: 0.0823 - val_accuracy: 0.9772 - val_auc: 0.9928
# Epoch 10/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9790 - auc: 0.9944 - val_loss: 0.0797 - val_accuracy: 0.9772 - val_auc: 0.9933
# Epoch 11/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9831 - auc: 0.9973 - val_loss: 0.0788 - val_accuracy: 0.9772 - val_auc: 0.9930
# Epoch 12/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 0.9825 - auc: 0.9973 - val_loss: 0.0795 - val_accuracy: 0.9747 - val_auc: 0.9930
# Epoch 13/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0569 - accuracy: 0.9834 - auc: 0.9955 - val_loss: 0.0843 - val_accuracy: 0.9772 - val_auc: 0.9936
# Epoch 14/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9752 - auc: 0.9935 - val_loss: 0.0785 - val_accuracy: 0.9772 - val_auc: 0.9931
# Epoch 15/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9799 - auc: 0.9932 - val_loss: 0.0798 - val_accuracy: 0.9747 - val_auc: 0.9928
# Epoch 16/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 0.9762 - auc: 0.9954 - val_loss: 0.0778 - val_accuracy: 0.9772 - val_auc: 0.9933
# Epoch 17/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9840 - auc: 0.9957 - val_loss: 0.0806 - val_accuracy: 0.9772 - val_auc: 0.9928
# Epoch 18/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0633 - accuracy: 0.9812 - auc: 0.9958 - val_loss: 0.0787 - val_accuracy: 0.9747 - val_auc: 0.9931
# Epoch 19/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9770 - auc: 0.9943 - val_loss: 0.0790 - val_accuracy: 0.9747 - val_auc: 0.9934
# Epoch 20/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9774 - auc: 0.9959 - val_loss: 0.0814 - val_accuracy: 0.9797 - val_auc: 0.9936
# Epoch 21/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9773 - auc: 0.9952 - val_loss: 0.0834 - val_accuracy: 0.9722 - val_auc: 0.9930
# Epoch 22/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9808 - auc: 0.9949 - val_loss: 0.0788 - val_accuracy: 0.9747 - val_auc: 0.9929
# Epoch 23/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9800 - auc: 0.9955 - val_loss: 0.0815 - val_accuracy: 0.9772 - val_auc: 0.9933
# Epoch 24/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9808 - auc: 0.9962 - val_loss: 0.0802 - val_accuracy: 0.9747 - val_auc: 0.9929
# Epoch 25/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9746 - auc: 0.9948 - val_loss: 0.0834 - val_accuracy: 0.9772 - val_auc: 0.9934
# Epoch 26/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9766 - auc: 0.9962 - val_loss: 0.0786 - val_accuracy: 0.9747 - val_auc: 0.9932
# Epoch 27/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9790 - auc: 0.9945 - val_loss: 0.0856 - val_accuracy: 0.9696 - val_auc: 0.9928
# Epoch 28/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9760 - auc: 0.9961 - val_loss: 0.0798 - val_accuracy: 0.9772 - val_auc: 0.9929
# Epoch 29/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9790 - auc: 0.9962 - val_loss: 0.0788 - val_accuracy: 0.9747 - val_auc: 0.9930
# Epoch 30/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 0.9788 - auc: 0.9929 - val_loss: 0.0818 - val_accuracy: 0.9722 - val_auc: 0.9926
# Epoch 31/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9785 - auc: 0.9943 - val_loss: 0.0802 - val_accuracy: 0.9797 - val_auc: 0.9933
# Epoch 32/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9785 - auc: 0.9961 - val_loss: 0.0824 - val_accuracy: 0.9722 - val_auc: 0.9930
# Epoch 33/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9790 - auc: 0.9954 - val_loss: 0.0834 - val_accuracy: 0.9722 - val_auc: 0.9929
# Epoch 34/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9789 - auc: 0.9958 - val_loss: 0.0795 - val_accuracy: 0.9747 - val_auc: 0.9933
# Epoch 35/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9816 - auc: 0.9961 - val_loss: 0.0826 - val_accuracy: 0.9797 - val_auc: 0.9934
# Epoch 36/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0757 - accuracy: 0.9763 - auc: 0.9931 - val_loss: 0.0789 - val_accuracy: 0.9747 - val_auc: 0.9931
# Epoch 37/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 0.9803 - auc: 0.9958 - val_loss: 0.0778 - val_accuracy: 0.9747 - val_auc: 0.9931
# Epoch 38/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0675 - accuracy: 0.9812 - auc: 0.9938 - val_loss: 0.0788 - val_accuracy: 0.9747 - val_auc: 0.9933
# Epoch 39/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9809 - auc: 0.9960 - val_loss: 0.0786 - val_accuracy: 0.9772 - val_auc: 0.9936
# Epoch 40/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.9817 - auc: 0.9956 - val_loss: 0.0819 - val_accuracy: 0.9772 - val_auc: 0.9933
# Epoch 41/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9815 - auc: 0.9959 - val_loss: 0.0795 - val_accuracy: 0.9747 - val_auc: 0.9930
# Epoch 42/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9781 - auc: 0.9944 - val_loss: 0.0864 - val_accuracy: 0.9722 - val_auc: 0.9932
# Epoch 43/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9788 - auc: 0.9956 - val_loss: 0.0786 - val_accuracy: 0.9772 - val_auc: 0.9932
# Epoch 44/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 0.9810 - auc: 0.9932 - val_loss: 0.0774 - val_accuracy: 0.9772 - val_auc: 0.9926
# Epoch 45/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0579 - accuracy: 0.9792 - auc: 0.9966 - val_loss: 0.0782 - val_accuracy: 0.9772 - val_auc: 0.9930
# Epoch 46/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9770 - auc: 0.9950 - val_loss: 0.0848 - val_accuracy: 0.9797 - val_auc: 0.9931
# Epoch 47/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9776 - auc: 0.9962 - val_loss: 0.0786 - val_accuracy: 0.9747 - val_auc: 0.9930
# Epoch 48/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9803 - auc: 0.9965 - val_loss: 0.0812 - val_accuracy: 0.9797 - val_auc: 0.9935
# Epoch 49/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0735 - accuracy: 0.9743 - auc: 0.9945 - val_loss: 0.0831 - val_accuracy: 0.9722 - val_auc: 0.9930
# Epoch 50/50
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9820 - auc: 0.9977 - val_loss: 0.0812 - val_accuracy: 0.9772 - val_auc: 0.9929

# %%
score = model.evaluate(X_test,y_test, verbose=0)
print(score)
print('Test accuracy:', score[1])
# Out:
# [0.12828904390335083, 0.9645569324493408, 0.9839913845062256]
# Test accuracy: 0.9645569324493408

# %%
model.save('reduct_Neural_net6.h5')

# %% [markdown]
# Model 1 reduct_Neural_net1.h5
#
# [0.14056071639060974, 0.9645569324493408, 0.9756771922111511]
# Test accuracy: 0.9645569324493408

# %% [markdown]
# Model 2 reduct_Neural_net2.h5
#
# [0.13930460810661316, 0.9670885801315308, 0.977031946182251]
# Test accuracy: 0.9670885801315308

# %% [markdown]
# Model 3 reduct_Neural_net3.h5
#
#
# [0.13574625551700592, 0.9683544039726257, 0.9755361676216125]
# Test accuracy: 0.9683544039726257

# %% [markdown]
# Model 4 : 'reduct_Neural_net4.h5'
#
#
# [0.13601592183113098, 0.9708860516548157, 0.977410614490509]
# Test accuracy: 0.9708860516548157

# %% [markdown]
# Model 5 : reduct_Neural_net5.h5
#
#
# [0.14051833748817444, 0.9734176993370056, 0.9761374592781067]
# Test accuracy: 0.9734176993370056

# %%
from keras.models import load_model
prevModel = load_model('reduct_Neural_net5.h5')

# %%
prevModel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 30)                2370
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                620
# _________________________________________________________________
# dense_14 (Dense)             (None, 15)                315
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 3,321
# Trainable params: 3,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
score = prevModel.evaluate(X_train,y_train, verbose=0)
print(score)
print('Train accuracy:', score[1])
# Out:
# [0.03959997743368149, 0.9895041584968567, 0.9969519376754761]
# Train accuracy: 0.9895041584968567

# %%
score = prevModel.evaluate(X_test,y_test, verbose=0)
print(score)
print('Test accuracy:', score[1])
# Out:
# [0.14051833748817444, 0.9734176993370056, 0.9761374592781067]
# Test accuracy: 0.9734176993370056

# %%
score = prevModel.evaluate(X_val,y_val, verbose=0)
print(score)
print('Validation accuracy:', score[1])
# Out:
# [0.05778713524341583, 0.9848101139068604, 0.9950857758522034]
# Validation accuracy: 0.9848101139068604
