# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import collections
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import  cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier


# %matplotlib inline
import os

# %%
df=pd.read_csv('pca_data.csv')
df.head()
# Out:
#           0         1         2         3  ...        12        13        14   15
# 0 -0.538430  0.457871  0.217406 -0.202846  ...  0.017330 -0.003406  0.102550  0.0
# 1 -0.455548 -0.007590  0.226425 -0.187979  ... -0.098653  0.033998 -0.202744  0.0
# 2 -0.460422 -0.299343 -0.163764  0.221461  ...  0.018982 -0.093837  0.031382  0.0
# 3 -0.551961 -0.016130 -0.241888 -0.032486  ...  0.093891 -0.309899  0.156194  0.0
# 4 -0.485033 -0.286505 -0.203140 -0.024412  ...  0.060865 -0.295249  0.012482  0.0
#
# [5 rows x 16 columns]

# %%
df.describe()
# Out:
#                   0             1  ...            14           15
# count  4.107000e+03  4.107000e+03  ...  4.107000e+03  4107.000000
# mean   6.039051e-17 -5.784946e-17  ... -6.247877e-17     0.666667
# std    9.643492e-01  7.365535e-01  ...  3.540434e-01     0.471462
# min   -1.348049e+00 -5.011534e-01  ... -2.307533e+00     0.000000
# 25%   -4.088329e-01 -2.815306e-01  ... -4.573471e-02     0.000000
# 50%   -3.545521e-01 -2.483050e-01  ...  1.830378e-02     1.000000
# 75%   -3.226783e-01  7.203271e-02  ...  9.413702e-02     1.000000
# max    3.007889e+00  4.534475e+00  ...  1.875939e+00     1.000000
#
# [8 rows x 16 columns]

# %%
df['0']
# Out:
# 0      -0.538430
# 1      -0.455548
# 2      -0.460422
# 3      -0.551961
# 4      -0.485033
#           ...
# 4102   -0.359538
# 4103   -0.382791
# 4104   -1.247451
# 4105   -0.567096
# 4106   -0.527159
# Name: 0, Length: 4107, dtype: float64

# %%
fig,ax=plt.subplots(nrows=3,ncols=5)
fig.set_figheight(5)
fig.set_figwidth(13)


for i in range(5):
  one = 3*i + 0;
  one1 = 3*i + 1;
  one2 = 3*i + 2;
  sns.distplot(df[str(one)],ax=ax[0, i])
  sns.distplot(df[str(one1)],ax=ax[1, i])
  sns.distplot(df[str(one2)],ax=ax[2, i])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Run this at night for an hour top get the plots

# print("                                              add/non-ad  vs   Features")
# fig,ax=plt.subplots(nrows=1,ncols=1)
# fig.set_figheight(15)
# fig.set_figwidth(18)
# # sns.stripplot(y=1558,x=0,data=df,ax=ax[0])
# # sns.stripplot(y=1558,x=1,data=df,ax=ax[1])
# # sns.stripplot(y=1558,x=2,data=df,ax=ax[2])

# for i in range(1):
#   sns.stripplot(y = str(15), x = str(i), data = df, ax=ax[i])

# plt.show()

# %%
# plt.figure(figsize=(15,10))
# sns.boxplot(x='15',y='1',data=df)
# plt.xlabel('label-add/non-ad')
# plt.ylabel('width')
# plt.title("Boxplot-  Target Vs Width ")
# plt.show()

# %%
# columns_for_visualization = list()
# for i in range(15):
#   columns_for_visualization.append(str(i))
# corr=df[columns_for_visualization].corr()
# fig, ax = plt.subplots(figsize=(15,15))
# sns.heatmap(corr,annot=True,linewidths=.5, ax=ax)

# %%
# ax = sns.violinplot(x="15", y="1",data=df,split=True,inner="quart")

# %%
fig,ax=plt.subplots(nrows=3,ncols=5)
fig.set_figheight(30)
fig.set_figwidth(50)


for i in range(5):
 one = 3*i + 0;
 one1 = 3*i + 1;
 one2 = 3*i + 2;
 sns.violinplot(x="15", y=str(one),data=df,split=True,inner="quart",ax=ax[0,i])
 sns.violinplot(x="15", y=str(one1),data=df,split=True,inner="quart",ax=ax[1,i])
 sns.violinplot(x="15", y=str(one2),data=df,split=True,inner="quart",ax=ax[2,i])

# %%
da=df.values
X=da[:,:-1]
y=da[:,-1]


xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.30,random_state=80)

# %%
def fit_models(classifiers,xtrain,ytrain):
    """This function fit multiple models by sklearn and return the dictionary with values as  objects of models"""
    models=collections.OrderedDict()
    for constructor in classifiers:
        obj=constructor()
        obj.fit(xtrain,ytrain)
        models[str(constructor).split(':')[0]]=obj
    return models

def classification_multi_report(ytest,models_array):
    """This function generate classification accuracy report for given input model objects"""
    for i in models_array:
        print('__________________________________________________')
        print('the model - '+str(i))
        print(classification_report(ytest,models_array[i].predict(xtest)))
def cross_Function(models,cv):
    """This function return cross validated accuray and the variance of given input model obejects"""
    accuracy={}
    for model in models:
        cross_val_array=cross_val_score(models[model],xtrain,ytrain,scoring='accuracy',cv=cv)
        accuracy[model]=[np.mean(cross_val_array),np.std(cross_val_array)]
    return accuracy

def multi_grid_search(param_grid_array,estimator_list,x,y):
    """This function calculate the grid search parameters and accuracy  for given input modles and return dictionary with each tupple containing accuracy and best parameters"""
    d={}
    count=0
    for i in estimator_list:
        gc=GridSearchCV(estimator=estimator_list[i],param_grid=param_grid_array[count],scoring ='accuracy',cv=5).fit(x,y)
        d[i]=(gc.best_params_,gc.best_score_)
        count+=1
    return d

# %%
classifiers=[SVC, KNeighborsClassifier, RandomForestClassifier, XGBClassifier, DecisionTreeClassifier]

# classifiers=[GaussianNB,SVC,KNeighborsClassifier]

model_list=fit_models(classifiers,xtrain,ytrain)

classification_multi_report(ytest,model_list)
# Out:
# __________________________________________________
# the model - <class 'sklearn.svm._classes.SVC'>
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.73      0.81       409
#          1.0       0.88      0.97      0.92       824
#
#     accuracy                           0.89      1233
#    macro avg       0.90      0.85      0.87      1233
# weighted avg       0.89      0.89      0.89      1233
#
# __________________________________________________
# the model - <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.95      0.94       409
#          1.0       0.97      0.96      0.97       824
#
#     accuracy                           0.96      1233
#    macro avg       0.95      0.95      0.95      1233
# weighted avg       0.96      0.96      0.96      1233
#
# __________________________________________________
# the model - <class 'sklearn.ensemble._forest.RandomForestClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.96      0.97       409
#          1.0       0.98      0.99      0.98       824
#
#     accuracy                           0.98      1233
#    macro avg       0.98      0.97      0.97      1233
# weighted avg       0.98      0.98      0.98      1233
#
# __________________________________________________
# the model - <class 'xgboost.sklearn.XGBClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92       409
#          1.0       0.96      0.96      0.96       824
#
#     accuracy                           0.95      1233
#    macro avg       0.94      0.94      0.94      1233
# weighted avg       0.95      0.95      0.95      1233
#
# __________________________________________________
# the model - <class 'sklearn.tree._classes.DecisionTreeClassifier'>
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.95       409
#          1.0       0.98      0.98      0.98       824
#
#     accuracy                           0.97      1233
#    macro avg       0.97      0.97      0.97      1233
# weighted avg       0.97      0.97      0.97      1233

# %%
obj=cross_Function(model_list,cv=20)
for model in obj:
    print('the model -'+str(model)+'has \n || crosss validated accuracy as  -> '+str(obj[model][0])+' | variance - '+str(obj[model][1])+' ||' )
    print('______________________________________________________________________________________________________________')
# Out:
# the model -<class 'sklearn.svm._classes.SVC'>has
#  || crosss validated accuracy as  -> 0.8837582556332556 | variance - 0.028380616806913436 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.neighbors._classification.KNeighborsClassifier'>has
#  || crosss validated accuracy as  -> 0.9429292929292927 | variance - 0.01729310649644686 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.ensemble._forest.RandomForestClassifier'>has
#  || crosss validated accuracy as  -> 0.9718264374514375 | variance - 0.013620580970403267 ||
# ______________________________________________________________________________________________________________
# the model -<class 'xgboost.sklearn.XGBClassifier'>has
#  || crosss validated accuracy as  -> 0.9460785742035739 | variance - 0.014197967441682975 ||
# ______________________________________________________________________________________________________________
# the model -<class 'sklearn.tree._classes.DecisionTreeClassifier'>has
#  || crosss validated accuracy as  -> 0.9530254467754465 | variance - 0.008778533310512177 ||
# ______________________________________________________________________________________________________________

# %%
param_grid_svm=[
  {
      
  }
]

param_grid_knn=[

    {   

        
    }
]

param_RandomForest = [
    {
        'n_estimators': np.arange(100, 500, 50),
        'max_depth' : np.arange(5, 35, 5)
    }
]

param_XGB=[
    {
        
    }
]

param_logit = [
  {
      
  }
]

param_XGBoost=[
    {

    }
]
param_dc = [
  {
      
  }
]
param_grid_array=[param_grid_svm, param_grid_knn, param_RandomForest, param_XGBoost, param_dc]
multi_grid_search(param_grid_array,model_list,xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2fcc4c6d18a3> in <module>()
#      43 ]
#      44 param_grid_array=[param_grid_svm, param_grid_knn, param_RandomForest, param_XGBoost, param_dc]
# ---> 45 multi_grid_search(param_grid_array,model_list,xtrain,ytrain)
#
# NameError: name 'model_list' is not defined

# %% [markdown]
# **Fitting model with best hyperparmater and cv score**

# %%
classifier=RandomForestClassifier(max_depth = 20, n_estimators = 300)
classifier.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# Confusion Matrix

# %%
sns.heatmap(pd.crosstab(ytest,classifier.predict(xtest)),cmap='coolwarm')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.show()

# %%
print(classification_report(ytest,classifier.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       409
#          1.0       0.98      0.98      0.98       824
#
#     accuracy                           0.98      1233
#    macro avg       0.98      0.97      0.98      1233
# weighted avg       0.98      0.98      0.98      1233

# %% [markdown]
# **NN karna hai**

# %%
#custom NN
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop,Adam

# %%
X_train1, X_test, y_train1, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train1, y_train1, test_size=0.125, random_state=1)

# %%
#model params
model=Sequential()
model.add(Dense(30, input_dim=X_train.shape[1], activation='relu', kernel_initializer='he_normal'))
# model.add(Dense(200,activation='sigmoid',input_shape=(15,)))
# model.add(Dropout(0.2))
# model.add(Dense(300,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dense(200,activation='sigmoid'))
# model.add(Dense(100,activation='sigmoid'))
model.add(Dense(30,activation='sigmoid'))
model.add(Dense(25,activation='sigmoid'))

# model.add(Dropout(0.2))
# model.add(Dense(20,activation='sigmoid'))
model.add(Dense(20,activation='sigmoid'))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10,activation='sigmoid'))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 30)                480
# _________________________________________________________________
# dense_31 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_32 (Dense)             (None, 25)                775
# _________________________________________________________________
# dense_33 (Dense)             (None, 20)                520
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 2,726
# Trainable params: 2,726
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy','AUC'])

# class_weights={0: 1,
#                 1:2.5,
#                 2: 5}
history = model.fit(X_train1, y_train1, batch_size=64, epochs=500, verbose=1, validation_data=(X_val, y_val))
# Out:
# Epoch 1/500
# 52/52 [==============================] - 1s 9ms/step - loss: 0.1391 - accuracy: 0.9577 - auc: 0.9804 - val_loss: 0.0981 - val_accuracy: 0.9732 - val_auc: 0.9913
# Epoch 2/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1140 - accuracy: 0.9697 - auc: 0.9868 - val_loss: 0.0992 - val_accuracy: 0.9757 - val_auc: 0.9907
# Epoch 3/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1220 - accuracy: 0.9635 - auc: 0.9845 - val_loss: 0.1033 - val_accuracy: 0.9635 - val_auc: 0.9915
# Epoch 4/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9592 - auc: 0.9815 - val_loss: 0.1169 - val_accuracy: 0.9538 - val_auc: 0.9909
# Epoch 5/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9587 - auc: 0.9832 - val_loss: 0.0965 - val_accuracy: 0.9781 - val_auc: 0.9916
# Epoch 6/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.9606 - auc: 0.9824 - val_loss: 0.1046 - val_accuracy: 0.9732 - val_auc: 0.9907
# Epoch 7/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.9627 - auc: 0.9839 - val_loss: 0.0971 - val_accuracy: 0.9732 - val_auc: 0.9910
# Epoch 8/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1132 - accuracy: 0.9676 - auc: 0.9858 - val_loss: 0.0966 - val_accuracy: 0.9757 - val_auc: 0.9909
# Epoch 9/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1249 - accuracy: 0.9671 - auc: 0.9827 - val_loss: 0.0949 - val_accuracy: 0.9781 - val_auc: 0.9915
# Epoch 10/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9567 - auc: 0.9798 - val_loss: 0.0932 - val_accuracy: 0.9781 - val_auc: 0.9917
# Epoch 11/500
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.9570 - auc: 0.9834 - val_loss: 0.0960 - val_accuracy: 0.9781 - val_auc: 0.9916
# Epoch 12/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9604 - auc: 0.9850 - val_loss: 0.0940 - val_accuracy: 0.9781 - val_auc: 0.9916
# Epoch 13/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.9649 - auc: 0.9829 - val_loss: 0.0985 - val_accuracy: 0.9732 - val_auc: 0.9912
# Epoch 14/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9609 - auc: 0.9854 - val_loss: 0.0976 - val_accuracy: 0.9757 - val_auc: 0.9916
# Epoch 15/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9665 - auc: 0.9848 - val_loss: 0.0964 - val_accuracy: 0.9781 - val_auc: 0.9915
# Epoch 16/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1326 - accuracy: 0.9588 - auc: 0.9824 - val_loss: 0.0926 - val_accuracy: 0.9781 - val_auc: 0.9917
# Epoch 17/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9611 - auc: 0.9841 - val_loss: 0.0929 - val_accuracy: 0.9781 - val_auc: 0.9917
# Epoch 18/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 0.9644 - auc: 0.9834 - val_loss: 0.0926 - val_accuracy: 0.9757 - val_auc: 0.9915
# Epoch 19/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9672 - auc: 0.9849 - val_loss: 0.0985 - val_accuracy: 0.9757 - val_auc: 0.9913
# Epoch 20/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1405 - accuracy: 0.9578 - auc: 0.9819 - val_loss: 0.1029 - val_accuracy: 0.9732 - val_auc: 0.9910
# Epoch 21/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1360 - accuracy: 0.9625 - auc: 0.9798 - val_loss: 0.1008 - val_accuracy: 0.9708 - val_auc: 0.9915
# Epoch 22/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.9600 - auc: 0.9850 - val_loss: 0.1152 - val_accuracy: 0.9538 - val_auc: 0.9915
# Epoch 23/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9583 - auc: 0.9840 - val_loss: 0.1000 - val_accuracy: 0.9732 - val_auc: 0.9910
# Epoch 24/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1330 - accuracy: 0.9548 - auc: 0.9813 - val_loss: 0.0989 - val_accuracy: 0.9732 - val_auc: 0.9911
# Epoch 25/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1371 - accuracy: 0.9606 - auc: 0.9822 - val_loss: 0.1111 - val_accuracy: 0.9635 - val_auc: 0.9910
# Epoch 26/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.9604 - auc: 0.9844 - val_loss: 0.0957 - val_accuracy: 0.9805 - val_auc: 0.9915
# Epoch 27/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9623 - auc: 0.9832 - val_loss: 0.0990 - val_accuracy: 0.9708 - val_auc: 0.9915
# Epoch 28/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.9594 - auc: 0.9815 - val_loss: 0.1045 - val_accuracy: 0.9659 - val_auc: 0.9909
# Epoch 29/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9587 - auc: 0.9817 - val_loss: 0.1132 - val_accuracy: 0.9586 - val_auc: 0.9916
# Epoch 30/500
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9593 - auc: 0.9841 - val_loss: 0.1037 - val_accuracy: 0.9708 - val_auc: 0.9911
# Epoch 31/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9646 - auc: 0.9840 - val_loss: 0.1013 - val_accuracy: 0.9757 - val_auc: 0.9894
# Epoch 32/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9625 - auc: 0.9835 - val_loss: 0.0998 - val_accuracy: 0.9708 - val_auc: 0.9905
# Epoch 33/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.9585 - auc: 0.9821 - val_loss: 0.0951 - val_accuracy: 0.9732 - val_auc: 0.9917
# Epoch 34/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9640 - auc: 0.9862 - val_loss: 0.0937 - val_accuracy: 0.9732 - val_auc: 0.9915
# Epoch 35/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1363 - accuracy: 0.9589 - auc: 0.9811 - val_loss: 0.0982 - val_accuracy: 0.9708 - val_auc: 0.9916
# Epoch 36/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9595 - auc: 0.9833 - val_loss: 0.0937 - val_accuracy: 0.9781 - val_auc: 0.9916
# Epoch 37/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9595 - auc: 0.9822 - val_loss: 0.0994 - val_accuracy: 0.9757 - val_auc: 0.9910
# Epoch 38/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1349 - accuracy: 0.9577 - auc: 0.9828 - val_loss: 0.0966 - val_accuracy: 0.9757 - val_auc: 0.9913
# Epoch 39/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1188 - accuracy: 0.9648 - auc: 0.9857 - val_loss: 0.0968 - val_accuracy: 0.9708 - val_auc: 0.9883
# Epoch 40/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.9634 - auc: 0.9844 - val_loss: 0.0995 - val_accuracy: 0.9684 - val_auc: 0.9915
# Epoch 41/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9641 - auc: 0.9840 - val_loss: 0.1001 - val_accuracy: 0.9684 - val_auc: 0.9913
# Epoch 42/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9695 - auc: 0.9861 - val_loss: 0.0955 - val_accuracy: 0.9781 - val_auc: 0.9917
# Epoch 43/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9603 - auc: 0.9826 - val_loss: 0.1067 - val_accuracy: 0.9635 - val_auc: 0.9897
# Epoch 44/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9594 - auc: 0.9849 - val_loss: 0.1012 - val_accuracy: 0.9757 - val_auc: 0.9894
# Epoch 45/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9692 - auc: 0.9868 - val_loss: 0.1021 - val_accuracy: 0.9781 - val_auc: 0.9894
# Epoch 46/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1160 - accuracy: 0.9632 - auc: 0.9841 - val_loss: 0.1116 - val_accuracy: 0.9635 - val_auc: 0.9858
# Epoch 47/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9600 - auc: 0.9804 - val_loss: 0.1041 - val_accuracy: 0.9684 - val_auc: 0.9902
# Epoch 48/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9641 - auc: 0.9828 - val_loss: 0.0985 - val_accuracy: 0.9757 - val_auc: 0.9914
# Epoch 49/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1289 - accuracy: 0.9614 - auc: 0.9829 - val_loss: 0.0982 - val_accuracy: 0.9708 - val_auc: 0.9922
# Epoch 50/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.9609 - auc: 0.9811 - val_loss: 0.0989 - val_accuracy: 0.9757 - val_auc: 0.9916
# Epoch 51/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.9661 - auc: 0.9849 - val_loss: 0.0929 - val_accuracy: 0.9757 - val_auc: 0.9916
# Epoch 52/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1145 - accuracy: 0.9666 - auc: 0.9863 - val_loss: 0.1111 - val_accuracy: 0.9635 - val_auc: 0.9895
# Epoch 53/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9580 - auc: 0.9825 - val_loss: 0.0996 - val_accuracy: 0.9757 - val_auc: 0.9898
# Epoch 54/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9630 - auc: 0.9834 - val_loss: 0.0977 - val_accuracy: 0.9781 - val_auc: 0.9897
# Epoch 55/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9660 - auc: 0.9828 - val_loss: 0.1028 - val_accuracy: 0.9757 - val_auc: 0.9896
# Epoch 56/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.9640 - auc: 0.9809 - val_loss: 0.1005 - val_accuracy: 0.9732 - val_auc: 0.9903
# Epoch 57/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9562 - auc: 0.9816 - val_loss: 0.0941 - val_accuracy: 0.9732 - val_auc: 0.9920
# Epoch 58/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9634 - auc: 0.9847 - val_loss: 0.1058 - val_accuracy: 0.9562 - val_auc: 0.9891
# Epoch 59/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1303 - accuracy: 0.9580 - auc: 0.9822 - val_loss: 0.1055 - val_accuracy: 0.9635 - val_auc: 0.9891
# Epoch 60/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1305 - accuracy: 0.9638 - auc: 0.9803 - val_loss: 0.0997 - val_accuracy: 0.9757 - val_auc: 0.9887
# Epoch 61/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9653 - auc: 0.9812 - val_loss: 0.1062 - val_accuracy: 0.9684 - val_auc: 0.9900
# Epoch 62/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1252 - accuracy: 0.9616 - auc: 0.9828 - val_loss: 0.1045 - val_accuracy: 0.9708 - val_auc: 0.9916
# Epoch 63/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9620 - auc: 0.9831 - val_loss: 0.0950 - val_accuracy: 0.9684 - val_auc: 0.9892
# Epoch 64/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9674 - auc: 0.9838 - val_loss: 0.0907 - val_accuracy: 0.9732 - val_auc: 0.9919
# Epoch 65/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.9616 - auc: 0.9847 - val_loss: 0.0976 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 66/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9625 - auc: 0.9844 - val_loss: 0.0921 - val_accuracy: 0.9757 - val_auc: 0.9919
# Epoch 67/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9627 - auc: 0.9841 - val_loss: 0.1025 - val_accuracy: 0.9684 - val_auc: 0.9895
# Epoch 68/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1407 - accuracy: 0.9578 - auc: 0.9793 - val_loss: 0.1000 - val_accuracy: 0.9757 - val_auc: 0.9897
# Epoch 69/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1318 - accuracy: 0.9625 - auc: 0.9816 - val_loss: 0.0983 - val_accuracy: 0.9732 - val_auc: 0.9897
# Epoch 70/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1314 - accuracy: 0.9633 - auc: 0.9813 - val_loss: 0.1068 - val_accuracy: 0.9708 - val_auc: 0.9889
# Epoch 71/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.9596 - auc: 0.9807 - val_loss: 0.1026 - val_accuracy: 0.9732 - val_auc: 0.9889
# Epoch 72/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9634 - auc: 0.9851 - val_loss: 0.0989 - val_accuracy: 0.9732 - val_auc: 0.9890
# Epoch 73/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1119 - accuracy: 0.9672 - auc: 0.9853 - val_loss: 0.0981 - val_accuracy: 0.9684 - val_auc: 0.9923
# Epoch 74/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.9625 - auc: 0.9840 - val_loss: 0.0910 - val_accuracy: 0.9805 - val_auc: 0.9923
# Epoch 75/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9619 - auc: 0.9842 - val_loss: 0.0995 - val_accuracy: 0.9659 - val_auc: 0.9883
# Epoch 76/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1342 - accuracy: 0.9600 - auc: 0.9824 - val_loss: 0.0920 - val_accuracy: 0.9757 - val_auc: 0.9925
# Epoch 77/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.9592 - auc: 0.9824 - val_loss: 0.0941 - val_accuracy: 0.9708 - val_auc: 0.9914
# Epoch 78/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1365 - accuracy: 0.9562 - auc: 0.9804 - val_loss: 0.0998 - val_accuracy: 0.9611 - val_auc: 0.9920
# Epoch 79/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1286 - accuracy: 0.9591 - auc: 0.9828 - val_loss: 0.1004 - val_accuracy: 0.9732 - val_auc: 0.9919
# Epoch 80/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1305 - accuracy: 0.9601 - auc: 0.9822 - val_loss: 0.0951 - val_accuracy: 0.9708 - val_auc: 0.9925
# Epoch 81/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9631 - auc: 0.9842 - val_loss: 0.0964 - val_accuracy: 0.9757 - val_auc: 0.9917
# Epoch 82/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9519 - auc: 0.9811 - val_loss: 0.0917 - val_accuracy: 0.9757 - val_auc: 0.9923
# Epoch 83/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9622 - auc: 0.9853 - val_loss: 0.0987 - val_accuracy: 0.9732 - val_auc: 0.9914
# Epoch 84/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9581 - auc: 0.9813 - val_loss: 0.0891 - val_accuracy: 0.9805 - val_auc: 0.9918
# Epoch 85/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9671 - auc: 0.9844 - val_loss: 0.0965 - val_accuracy: 0.9757 - val_auc: 0.9893
# Epoch 86/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9699 - auc: 0.9867 - val_loss: 0.0984 - val_accuracy: 0.9684 - val_auc: 0.9895
# Epoch 87/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9563 - auc: 0.9798 - val_loss: 0.0981 - val_accuracy: 0.9732 - val_auc: 0.9894
# Epoch 88/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.9619 - auc: 0.9803 - val_loss: 0.1016 - val_accuracy: 0.9684 - val_auc: 0.9891
# Epoch 89/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9609 - auc: 0.9827 - val_loss: 0.0972 - val_accuracy: 0.9757 - val_auc: 0.9888
# Epoch 90/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1436 - accuracy: 0.9572 - auc: 0.9774 - val_loss: 0.0983 - val_accuracy: 0.9757 - val_auc: 0.9886
# Epoch 91/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1300 - accuracy: 0.9610 - auc: 0.9806 - val_loss: 0.1005 - val_accuracy: 0.9732 - val_auc: 0.9890
# Epoch 92/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.9607 - auc: 0.9799 - val_loss: 0.0972 - val_accuracy: 0.9732 - val_auc: 0.9893
# Epoch 93/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9647 - auc: 0.9835 - val_loss: 0.0960 - val_accuracy: 0.9757 - val_auc: 0.9892
# Epoch 94/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1114 - accuracy: 0.9699 - auc: 0.9847 - val_loss: 0.0967 - val_accuracy: 0.9757 - val_auc: 0.9890
# Epoch 95/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1086 - accuracy: 0.9666 - auc: 0.9864 - val_loss: 0.1061 - val_accuracy: 0.9635 - val_auc: 0.9892
# Epoch 96/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.9572 - auc: 0.9799 - val_loss: 0.0963 - val_accuracy: 0.9757 - val_auc: 0.9889
# Epoch 97/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.9645 - auc: 0.9830 - val_loss: 0.0999 - val_accuracy: 0.9684 - val_auc: 0.9887
# Epoch 98/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9664 - auc: 0.9837 - val_loss: 0.0988 - val_accuracy: 0.9757 - val_auc: 0.9888
# Epoch 99/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1326 - accuracy: 0.9576 - auc: 0.9803 - val_loss: 0.1010 - val_accuracy: 0.9708 - val_auc: 0.9900
# Epoch 100/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9670 - auc: 0.9847 - val_loss: 0.1038 - val_accuracy: 0.9659 - val_auc: 0.9859
# Epoch 101/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.9536 - auc: 0.9812 - val_loss: 0.0986 - val_accuracy: 0.9732 - val_auc: 0.9890
# Epoch 102/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1199 - accuracy: 0.9628 - auc: 0.9840 - val_loss: 0.1021 - val_accuracy: 0.9708 - val_auc: 0.9888
# Epoch 103/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9634 - auc: 0.9855 - val_loss: 0.0998 - val_accuracy: 0.9732 - val_auc: 0.9904
# Epoch 104/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 0.9577 - auc: 0.9815 - val_loss: 0.1030 - val_accuracy: 0.9684 - val_auc: 0.9902
# Epoch 105/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.9637 - auc: 0.9817 - val_loss: 0.0976 - val_accuracy: 0.9757 - val_auc: 0.9904
# Epoch 106/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1270 - accuracy: 0.9593 - auc: 0.9824 - val_loss: 0.1032 - val_accuracy: 0.9635 - val_auc: 0.9902
# Epoch 107/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.9641 - auc: 0.9831 - val_loss: 0.0958 - val_accuracy: 0.9781 - val_auc: 0.9904
# Epoch 108/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1284 - accuracy: 0.9609 - auc: 0.9814 - val_loss: 0.0984 - val_accuracy: 0.9732 - val_auc: 0.9900
# Epoch 109/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1402 - accuracy: 0.9623 - auc: 0.9782 - val_loss: 0.0958 - val_accuracy: 0.9757 - val_auc: 0.9900
# Epoch 110/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1149 - accuracy: 0.9659 - auc: 0.9845 - val_loss: 0.1007 - val_accuracy: 0.9684 - val_auc: 0.9903
# Epoch 111/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9616 - auc: 0.9848 - val_loss: 0.1036 - val_accuracy: 0.9684 - val_auc: 0.9902
# Epoch 112/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1264 - accuracy: 0.9620 - auc: 0.9823 - val_loss: 0.0958 - val_accuracy: 0.9781 - val_auc: 0.9902
# Epoch 113/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.9644 - auc: 0.9833 - val_loss: 0.0982 - val_accuracy: 0.9708 - val_auc: 0.9902
# Epoch 114/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9567 - auc: 0.9823 - val_loss: 0.0993 - val_accuracy: 0.9732 - val_auc: 0.9902
# Epoch 115/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1348 - accuracy: 0.9584 - auc: 0.9813 - val_loss: 0.1004 - val_accuracy: 0.9708 - val_auc: 0.9902
# Epoch 116/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9632 - auc: 0.9834 - val_loss: 0.0950 - val_accuracy: 0.9781 - val_auc: 0.9903
# Epoch 117/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1076 - accuracy: 0.9685 - auc: 0.9866 - val_loss: 0.1068 - val_accuracy: 0.9659 - val_auc: 0.9897
# Epoch 118/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9612 - auc: 0.9835 - val_loss: 0.0952 - val_accuracy: 0.9781 - val_auc: 0.9900
# Epoch 119/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.9591 - auc: 0.9796 - val_loss: 0.0992 - val_accuracy: 0.9732 - val_auc: 0.9908
# Epoch 120/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1369 - accuracy: 0.9548 - auc: 0.9813 - val_loss: 0.1031 - val_accuracy: 0.9684 - val_auc: 0.9906
# Epoch 121/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9598 - auc: 0.9831 - val_loss: 0.0969 - val_accuracy: 0.9708 - val_auc: 0.9902
# Epoch 122/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9565 - auc: 0.9818 - val_loss: 0.0961 - val_accuracy: 0.9757 - val_auc: 0.9903
# Epoch 123/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9639 - auc: 0.9822 - val_loss: 0.0994 - val_accuracy: 0.9781 - val_auc: 0.9904
# Epoch 124/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9602 - auc: 0.9802 - val_loss: 0.0973 - val_accuracy: 0.9732 - val_auc: 0.9901
# Epoch 125/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9631 - auc: 0.9868 - val_loss: 0.0972 - val_accuracy: 0.9757 - val_auc: 0.9902
# Epoch 126/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.9607 - auc: 0.9804 - val_loss: 0.0983 - val_accuracy: 0.9684 - val_auc: 0.9905
# Epoch 127/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1427 - accuracy: 0.9543 - auc: 0.9796 - val_loss: 0.0943 - val_accuracy: 0.9757 - val_auc: 0.9905
# Epoch 128/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1092 - accuracy: 0.9675 - auc: 0.9871 - val_loss: 0.0980 - val_accuracy: 0.9732 - val_auc: 0.9908
# Epoch 129/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9633 - auc: 0.9850 - val_loss: 0.0969 - val_accuracy: 0.9732 - val_auc: 0.9904
# Epoch 130/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9654 - auc: 0.9855 - val_loss: 0.1059 - val_accuracy: 0.9659 - val_auc: 0.9896
# Epoch 131/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1127 - accuracy: 0.9662 - auc: 0.9865 - val_loss: 0.0973 - val_accuracy: 0.9708 - val_auc: 0.9904
# Epoch 132/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9626 - auc: 0.9838 - val_loss: 0.0970 - val_accuracy: 0.9757 - val_auc: 0.9896
# Epoch 133/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9566 - auc: 0.9825 - val_loss: 0.0973 - val_accuracy: 0.9757 - val_auc: 0.9897
# Epoch 134/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9671 - auc: 0.9825 - val_loss: 0.0991 - val_accuracy: 0.9757 - val_auc: 0.9898
# Epoch 135/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1280 - accuracy: 0.9574 - auc: 0.9833 - val_loss: 0.1142 - val_accuracy: 0.9635 - val_auc: 0.9904
# Epoch 136/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9536 - auc: 0.9825 - val_loss: 0.0952 - val_accuracy: 0.9757 - val_auc: 0.9910
# Epoch 137/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9622 - auc: 0.9800 - val_loss: 0.0980 - val_accuracy: 0.9708 - val_auc: 0.9899
# Epoch 138/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9639 - auc: 0.9834 - val_loss: 0.0960 - val_accuracy: 0.9757 - val_auc: 0.9907
# Epoch 139/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.9696 - auc: 0.9815 - val_loss: 0.1007 - val_accuracy: 0.9732 - val_auc: 0.9889
# Epoch 140/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9654 - auc: 0.9814 - val_loss: 0.0976 - val_accuracy: 0.9732 - val_auc: 0.9904
# Epoch 141/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1153 - accuracy: 0.9652 - auc: 0.9853 - val_loss: 0.1033 - val_accuracy: 0.9635 - val_auc: 0.9904
# Epoch 142/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1212 - accuracy: 0.9600 - auc: 0.9843 - val_loss: 0.0955 - val_accuracy: 0.9781 - val_auc: 0.9902
# Epoch 143/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9698 - auc: 0.9860 - val_loss: 0.0972 - val_accuracy: 0.9732 - val_auc: 0.9905
# Epoch 144/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9691 - auc: 0.9861 - val_loss: 0.1157 - val_accuracy: 0.9513 - val_auc: 0.9909
# Epoch 145/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9654 - auc: 0.9847 - val_loss: 0.0980 - val_accuracy: 0.9659 - val_auc: 0.9910
# Epoch 146/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9651 - auc: 0.9840 - val_loss: 0.1042 - val_accuracy: 0.9611 - val_auc: 0.9901
# Epoch 147/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.9595 - auc: 0.9828 - val_loss: 0.0945 - val_accuracy: 0.9757 - val_auc: 0.9900
# Epoch 148/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9647 - auc: 0.9825 - val_loss: 0.0945 - val_accuracy: 0.9781 - val_auc: 0.9899
# Epoch 149/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9552 - auc: 0.9808 - val_loss: 0.0935 - val_accuracy: 0.9781 - val_auc: 0.9897
# Epoch 150/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1212 - accuracy: 0.9630 - auc: 0.9838 - val_loss: 0.0971 - val_accuracy: 0.9757 - val_auc: 0.9904
# Epoch 151/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9644 - auc: 0.9845 - val_loss: 0.0975 - val_accuracy: 0.9659 - val_auc: 0.9907
# Epoch 152/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1158 - accuracy: 0.9629 - auc: 0.9858 - val_loss: 0.0936 - val_accuracy: 0.9732 - val_auc: 0.9894
# Epoch 153/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1190 - accuracy: 0.9651 - auc: 0.9833 - val_loss: 0.0943 - val_accuracy: 0.9781 - val_auc: 0.9897
# Epoch 154/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1169 - accuracy: 0.9632 - auc: 0.9835 - val_loss: 0.0921 - val_accuracy: 0.9781 - val_auc: 0.9910
# Epoch 155/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9669 - auc: 0.9838 - val_loss: 0.1013 - val_accuracy: 0.9684 - val_auc: 0.9911
# Epoch 156/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9584 - auc: 0.9786 - val_loss: 0.1042 - val_accuracy: 0.9708 - val_auc: 0.9893
# Epoch 157/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.9608 - auc: 0.9834 - val_loss: 0.0936 - val_accuracy: 0.9757 - val_auc: 0.9911
# Epoch 158/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9691 - auc: 0.9850 - val_loss: 0.0980 - val_accuracy: 0.9684 - val_auc: 0.9904
# Epoch 159/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9612 - auc: 0.9839 - val_loss: 0.0942 - val_accuracy: 0.9757 - val_auc: 0.9898
# Epoch 160/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9665 - auc: 0.9840 - val_loss: 0.1102 - val_accuracy: 0.9635 - val_auc: 0.9909
# Epoch 161/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.9606 - auc: 0.9836 - val_loss: 0.1059 - val_accuracy: 0.9659 - val_auc: 0.9900
# Epoch 162/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9637 - auc: 0.9834 - val_loss: 0.0937 - val_accuracy: 0.9781 - val_auc: 0.9905
# Epoch 163/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 0.9675 - auc: 0.9870 - val_loss: 0.0926 - val_accuracy: 0.9781 - val_auc: 0.9901
# Epoch 164/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.9649 - auc: 0.9817 - val_loss: 0.0930 - val_accuracy: 0.9708 - val_auc: 0.9898
# Epoch 165/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9673 - auc: 0.9841 - val_loss: 0.1021 - val_accuracy: 0.9684 - val_auc: 0.9902
# Epoch 166/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9651 - auc: 0.9835 - val_loss: 0.0962 - val_accuracy: 0.9732 - val_auc: 0.9902
# Epoch 167/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9630 - auc: 0.9806 - val_loss: 0.0983 - val_accuracy: 0.9732 - val_auc: 0.9912
# Epoch 168/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9612 - auc: 0.9819 - val_loss: 0.0944 - val_accuracy: 0.9732 - val_auc: 0.9899
# Epoch 169/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9592 - auc: 0.9796 - val_loss: 0.0962 - val_accuracy: 0.9732 - val_auc: 0.9902
# Epoch 170/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 0.9619 - auc: 0.9819 - val_loss: 0.0933 - val_accuracy: 0.9781 - val_auc: 0.9903
# Epoch 171/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9624 - auc: 0.9813 - val_loss: 0.1029 - val_accuracy: 0.9684 - val_auc: 0.9898
# Epoch 172/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9681 - auc: 0.9838 - val_loss: 0.1341 - val_accuracy: 0.9489 - val_auc: 0.9912
# Epoch 173/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 0.9537 - auc: 0.9814 - val_loss: 0.0997 - val_accuracy: 0.9708 - val_auc: 0.9900
# Epoch 174/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.9629 - auc: 0.9815 - val_loss: 0.0933 - val_accuracy: 0.9781 - val_auc: 0.9910
# Epoch 175/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9658 - auc: 0.9835 - val_loss: 0.0983 - val_accuracy: 0.9708 - val_auc: 0.9900
# Epoch 176/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9634 - auc: 0.9827 - val_loss: 0.0925 - val_accuracy: 0.9757 - val_auc: 0.9903
# Epoch 177/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1185 - accuracy: 0.9656 - auc: 0.9832 - val_loss: 0.0955 - val_accuracy: 0.9708 - val_auc: 0.9910
# Epoch 178/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9576 - auc: 0.9804 - val_loss: 0.0989 - val_accuracy: 0.9684 - val_auc: 0.9918
# Epoch 179/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1310 - accuracy: 0.9536 - auc: 0.9819 - val_loss: 0.0932 - val_accuracy: 0.9781 - val_auc: 0.9913
# Epoch 180/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9624 - auc: 0.9824 - val_loss: 0.0955 - val_accuracy: 0.9781 - val_auc: 0.9918
# Epoch 181/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 0.9623 - auc: 0.9847 - val_loss: 0.1003 - val_accuracy: 0.9708 - val_auc: 0.9902
# Epoch 182/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9658 - auc: 0.9829 - val_loss: 0.0952 - val_accuracy: 0.9708 - val_auc: 0.9916
# Epoch 183/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1163 - accuracy: 0.9655 - auc: 0.9831 - val_loss: 0.0951 - val_accuracy: 0.9659 - val_auc: 0.9912
# Epoch 184/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1149 - accuracy: 0.9660 - auc: 0.9840 - val_loss: 0.0929 - val_accuracy: 0.9757 - val_auc: 0.9902
# Epoch 185/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1115 - accuracy: 0.9673 - auc: 0.9839 - val_loss: 0.0933 - val_accuracy: 0.9781 - val_auc: 0.9916
# Epoch 186/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9640 - auc: 0.9854 - val_loss: 0.0972 - val_accuracy: 0.9732 - val_auc: 0.9911
# Epoch 187/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.9685 - auc: 0.9853 - val_loss: 0.1015 - val_accuracy: 0.9635 - val_auc: 0.9907
# Epoch 188/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.9595 - auc: 0.9827 - val_loss: 0.1020 - val_accuracy: 0.9684 - val_auc: 0.9883
# Epoch 189/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9613 - auc: 0.9828 - val_loss: 0.0921 - val_accuracy: 0.9757 - val_auc: 0.9901
# Epoch 190/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9622 - auc: 0.9811 - val_loss: 0.0930 - val_accuracy: 0.9781 - val_auc: 0.9916
# Epoch 191/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9566 - auc: 0.9834 - val_loss: 0.0963 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 192/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9553 - auc: 0.9813 - val_loss: 0.0966 - val_accuracy: 0.9684 - val_auc: 0.9914
# Epoch 193/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9626 - auc: 0.9835 - val_loss: 0.0934 - val_accuracy: 0.9732 - val_auc: 0.9912
# Epoch 194/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1190 - accuracy: 0.9648 - auc: 0.9841 - val_loss: 0.0953 - val_accuracy: 0.9757 - val_auc: 0.9922
# Epoch 195/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9601 - auc: 0.9858 - val_loss: 0.0986 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 196/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.9628 - auc: 0.9833 - val_loss: 0.0944 - val_accuracy: 0.9781 - val_auc: 0.9917
# Epoch 197/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1252 - accuracy: 0.9647 - auc: 0.9800 - val_loss: 0.0996 - val_accuracy: 0.9708 - val_auc: 0.9918
# Epoch 198/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 0.9692 - auc: 0.9859 - val_loss: 0.0938 - val_accuracy: 0.9757 - val_auc: 0.9914
# Epoch 199/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9624 - auc: 0.9832 - val_loss: 0.0921 - val_accuracy: 0.9781 - val_auc: 0.9919
# Epoch 200/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9607 - auc: 0.9819 - val_loss: 0.0969 - val_accuracy: 0.9684 - val_auc: 0.9919
# Epoch 201/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 0.9685 - auc: 0.9871 - val_loss: 0.0920 - val_accuracy: 0.9757 - val_auc: 0.9903
# Epoch 202/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9644 - auc: 0.9819 - val_loss: 0.0944 - val_accuracy: 0.9732 - val_auc: 0.9902
# Epoch 203/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1249 - accuracy: 0.9606 - auc: 0.9810 - val_loss: 0.0928 - val_accuracy: 0.9732 - val_auc: 0.9915
# Epoch 204/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9723 - auc: 0.9859 - val_loss: 0.0960 - val_accuracy: 0.9732 - val_auc: 0.9912
# Epoch 205/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9626 - auc: 0.9845 - val_loss: 0.0944 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 206/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1133 - accuracy: 0.9664 - auc: 0.9854 - val_loss: 0.0908 - val_accuracy: 0.9757 - val_auc: 0.9917
# Epoch 207/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1341 - accuracy: 0.9609 - auc: 0.9799 - val_loss: 0.0925 - val_accuracy: 0.9708 - val_auc: 0.9916
# Epoch 208/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1190 - accuracy: 0.9623 - auc: 0.9835 - val_loss: 0.0903 - val_accuracy: 0.9781 - val_auc: 0.9918
# Epoch 209/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1077 - accuracy: 0.9691 - auc: 0.9875 - val_loss: 0.0992 - val_accuracy: 0.9659 - val_auc: 0.9913
# Epoch 210/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1212 - accuracy: 0.9630 - auc: 0.9831 - val_loss: 0.0949 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 211/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9663 - auc: 0.9832 - val_loss: 0.0922 - val_accuracy: 0.9708 - val_auc: 0.9901
# Epoch 212/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9624 - auc: 0.9824 - val_loss: 0.0997 - val_accuracy: 0.9708 - val_auc: 0.9911
# Epoch 213/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9673 - auc: 0.9837 - val_loss: 0.0955 - val_accuracy: 0.9684 - val_auc: 0.9905
# Epoch 214/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.9638 - auc: 0.9856 - val_loss: 0.0947 - val_accuracy: 0.9684 - val_auc: 0.9919
# Epoch 215/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1149 - accuracy: 0.9632 - auc: 0.9842 - val_loss: 0.0961 - val_accuracy: 0.9659 - val_auc: 0.9906
# Epoch 216/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1253 - accuracy: 0.9594 - auc: 0.9820 - val_loss: 0.0980 - val_accuracy: 0.9635 - val_auc: 0.9913
# Epoch 217/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9610 - auc: 0.9851 - val_loss: 0.0924 - val_accuracy: 0.9684 - val_auc: 0.9915
# Epoch 218/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1215 - accuracy: 0.9622 - auc: 0.9833 - val_loss: 0.0970 - val_accuracy: 0.9635 - val_auc: 0.9922
# Epoch 219/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1258 - accuracy: 0.9595 - auc: 0.9835 - val_loss: 0.0972 - val_accuracy: 0.9635 - val_auc: 0.9913
# Epoch 220/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1334 - accuracy: 0.9566 - auc: 0.9825 - val_loss: 0.0897 - val_accuracy: 0.9757 - val_auc: 0.9917
# Epoch 221/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1018 - accuracy: 0.9681 - auc: 0.9878 - val_loss: 0.1019 - val_accuracy: 0.9708 - val_auc: 0.9919
# Epoch 222/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1162 - accuracy: 0.9625 - auc: 0.9836 - val_loss: 0.0912 - val_accuracy: 0.9781 - val_auc: 0.9919
# Epoch 223/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1108 - accuracy: 0.9675 - auc: 0.9844 - val_loss: 0.0979 - val_accuracy: 0.9684 - val_auc: 0.9920
# Epoch 224/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9571 - auc: 0.9825 - val_loss: 0.0901 - val_accuracy: 0.9757 - val_auc: 0.9917
# Epoch 225/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9654 - auc: 0.9822 - val_loss: 0.1126 - val_accuracy: 0.9513 - val_auc: 0.9928
# Epoch 226/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9630 - auc: 0.9856 - val_loss: 0.0951 - val_accuracy: 0.9708 - val_auc: 0.9923
# Epoch 227/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9670 - auc: 0.9866 - val_loss: 0.0901 - val_accuracy: 0.9732 - val_auc: 0.9918
# Epoch 228/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1266 - accuracy: 0.9600 - auc: 0.9824 - val_loss: 0.0934 - val_accuracy: 0.9757 - val_auc: 0.9916
# Epoch 229/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1145 - accuracy: 0.9651 - auc: 0.9857 - val_loss: 0.0906 - val_accuracy: 0.9757 - val_auc: 0.9921
# Epoch 230/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9677 - auc: 0.9864 - val_loss: 0.0908 - val_accuracy: 0.9781 - val_auc: 0.9921
# Epoch 231/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1199 - accuracy: 0.9640 - auc: 0.9834 - val_loss: 0.0953 - val_accuracy: 0.9684 - val_auc: 0.9913
# Epoch 232/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1168 - accuracy: 0.9629 - auc: 0.9846 - val_loss: 0.0872 - val_accuracy: 0.9781 - val_auc: 0.9921
# Epoch 233/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.9598 - auc: 0.9830 - val_loss: 0.0896 - val_accuracy: 0.9757 - val_auc: 0.9924
# Epoch 234/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9613 - auc: 0.9840 - val_loss: 0.0946 - val_accuracy: 0.9732 - val_auc: 0.9917
# Epoch 235/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1377 - accuracy: 0.9567 - auc: 0.9806 - val_loss: 0.0930 - val_accuracy: 0.9732 - val_auc: 0.9922
# Epoch 236/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9630 - auc: 0.9838 - val_loss: 0.0989 - val_accuracy: 0.9659 - val_auc: 0.9925
# Epoch 237/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9656 - auc: 0.9820 - val_loss: 0.0921 - val_accuracy: 0.9757 - val_auc: 0.9917
# Epoch 238/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1095 - accuracy: 0.9637 - auc: 0.9863 - val_loss: 0.1006 - val_accuracy: 0.9635 - val_auc: 0.9924
# Epoch 239/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.9637 - auc: 0.9846 - val_loss: 0.0939 - val_accuracy: 0.9684 - val_auc: 0.9917
# Epoch 240/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9608 - auc: 0.9799 - val_loss: 0.1053 - val_accuracy: 0.9659 - val_auc: 0.9909
# Epoch 241/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1115 - accuracy: 0.9657 - auc: 0.9855 - val_loss: 0.0927 - val_accuracy: 0.9708 - val_auc: 0.9916
# Epoch 242/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9653 - auc: 0.9839 - val_loss: 0.1016 - val_accuracy: 0.9684 - val_auc: 0.9909
# Epoch 243/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1142 - accuracy: 0.9619 - auc: 0.9853 - val_loss: 0.0882 - val_accuracy: 0.9781 - val_auc: 0.9922
# Epoch 244/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9671 - auc: 0.9834 - val_loss: 0.0906 - val_accuracy: 0.9732 - val_auc: 0.9920
# Epoch 245/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9601 - auc: 0.9848 - val_loss: 0.0894 - val_accuracy: 0.9732 - val_auc: 0.9923
# Epoch 246/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9664 - auc: 0.9866 - val_loss: 0.0909 - val_accuracy: 0.9708 - val_auc: 0.9925
# Epoch 247/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9654 - auc: 0.9824 - val_loss: 0.0928 - val_accuracy: 0.9805 - val_auc: 0.9920
# Epoch 248/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1154 - accuracy: 0.9609 - auc: 0.9842 - val_loss: 0.0976 - val_accuracy: 0.9684 - val_auc: 0.9925
# Epoch 249/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1047 - accuracy: 0.9709 - auc: 0.9861 - val_loss: 0.0937 - val_accuracy: 0.9757 - val_auc: 0.9923
# Epoch 250/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 0.9581 - auc: 0.9810 - val_loss: 0.0910 - val_accuracy: 0.9757 - val_auc: 0.9918
# Epoch 251/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9623 - auc: 0.9857 - val_loss: 0.0912 - val_accuracy: 0.9732 - val_auc: 0.9923
# Epoch 252/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9642 - auc: 0.9824 - val_loss: 0.0903 - val_accuracy: 0.9732 - val_auc: 0.9921
# Epoch 253/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.9655 - auc: 0.9862 - val_loss: 0.0943 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 254/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.9624 - auc: 0.9827 - val_loss: 0.0894 - val_accuracy: 0.9708 - val_auc: 0.9918
# Epoch 255/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9641 - auc: 0.9814 - val_loss: 0.0940 - val_accuracy: 0.9659 - val_auc: 0.9924
# Epoch 256/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9723 - auc: 0.9901 - val_loss: 0.0883 - val_accuracy: 0.9757 - val_auc: 0.9921
# Epoch 257/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.9678 - auc: 0.9841 - val_loss: 0.0925 - val_accuracy: 0.9708 - val_auc: 0.9920
# Epoch 258/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.9644 - auc: 0.9859 - val_loss: 0.0892 - val_accuracy: 0.9732 - val_auc: 0.9920
# Epoch 259/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1061 - accuracy: 0.9671 - auc: 0.9861 - val_loss: 0.0927 - val_accuracy: 0.9781 - val_auc: 0.9919
# Epoch 260/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9586 - auc: 0.9845 - val_loss: 0.0944 - val_accuracy: 0.9708 - val_auc: 0.9921
# Epoch 261/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9698 - auc: 0.9877 - val_loss: 0.0938 - val_accuracy: 0.9732 - val_auc: 0.9921
# Epoch 262/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9650 - auc: 0.9852 - val_loss: 0.0902 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 263/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1099 - accuracy: 0.9662 - auc: 0.9861 - val_loss: 0.0984 - val_accuracy: 0.9684 - val_auc: 0.9928
# Epoch 264/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1152 - accuracy: 0.9609 - auc: 0.9870 - val_loss: 0.0878 - val_accuracy: 0.9757 - val_auc: 0.9923
# Epoch 265/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.9601 - auc: 0.9839 - val_loss: 0.0885 - val_accuracy: 0.9757 - val_auc: 0.9920
# Epoch 266/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9564 - auc: 0.9813 - val_loss: 0.0903 - val_accuracy: 0.9757 - val_auc: 0.9920
# Epoch 267/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9609 - auc: 0.9808 - val_loss: 0.0896 - val_accuracy: 0.9732 - val_auc: 0.9922
# Epoch 268/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.9616 - auc: 0.9825 - val_loss: 0.0883 - val_accuracy: 0.9757 - val_auc: 0.9926
# Epoch 269/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9631 - auc: 0.9819 - val_loss: 0.0899 - val_accuracy: 0.9757 - val_auc: 0.9925
# Epoch 270/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1143 - accuracy: 0.9638 - auc: 0.9847 - val_loss: 0.0922 - val_accuracy: 0.9708 - val_auc: 0.9917
# Epoch 271/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0959 - accuracy: 0.9722 - auc: 0.9888 - val_loss: 0.0947 - val_accuracy: 0.9659 - val_auc: 0.9929
# Epoch 272/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9667 - auc: 0.9881 - val_loss: 0.0884 - val_accuracy: 0.9781 - val_auc: 0.9925
# Epoch 273/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9617 - auc: 0.9817 - val_loss: 0.0960 - val_accuracy: 0.9659 - val_auc: 0.9915
# Epoch 274/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9657 - auc: 0.9837 - val_loss: 0.0939 - val_accuracy: 0.9684 - val_auc: 0.9927
# Epoch 275/500
# ...
# Epoch 410/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1154 - accuracy: 0.9638 - auc: 0.9847 - val_loss: 0.0895 - val_accuracy: 0.9708 - val_auc: 0.9932
# Epoch 411/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.9645 - auc: 0.9847 - val_loss: 0.0877 - val_accuracy: 0.9708 - val_auc: 0.9931
# Epoch 412/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1138 - accuracy: 0.9671 - auc: 0.9846 - val_loss: 0.0859 - val_accuracy: 0.9732 - val_auc: 0.9916
# Epoch 413/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1098 - accuracy: 0.9653 - auc: 0.9864 - val_loss: 0.0851 - val_accuracy: 0.9781 - val_auc: 0.9923
# Epoch 414/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1003 - accuracy: 0.9722 - auc: 0.9876 - val_loss: 0.0802 - val_accuracy: 0.9781 - val_auc: 0.9927
# Epoch 415/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9712 - auc: 0.9866 - val_loss: 0.0869 - val_accuracy: 0.9732 - val_auc: 0.9917
# Epoch 416/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.9635 - auc: 0.9844 - val_loss: 0.0921 - val_accuracy: 0.9757 - val_auc: 0.9922
# Epoch 417/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9699 - auc: 0.9882 - val_loss: 0.0826 - val_accuracy: 0.9781 - val_auc: 0.9929
# Epoch 418/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1123 - accuracy: 0.9673 - auc: 0.9834 - val_loss: 0.1066 - val_accuracy: 0.9586 - val_auc: 0.9913
# Epoch 419/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9565 - auc: 0.9849 - val_loss: 0.0850 - val_accuracy: 0.9757 - val_auc: 0.9934
# Epoch 420/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9646 - auc: 0.9845 - val_loss: 0.0846 - val_accuracy: 0.9757 - val_auc: 0.9921
# Epoch 421/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 0.9659 - auc: 0.9862 - val_loss: 0.0853 - val_accuracy: 0.9805 - val_auc: 0.9928
# Epoch 422/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9632 - auc: 0.9838 - val_loss: 0.0851 - val_accuracy: 0.9757 - val_auc: 0.9938
# Epoch 423/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1111 - accuracy: 0.9700 - auc: 0.9838 - val_loss: 0.0805 - val_accuracy: 0.9805 - val_auc: 0.9931
# Epoch 424/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9652 - auc: 0.9834 - val_loss: 0.0869 - val_accuracy: 0.9732 - val_auc: 0.9926
# Epoch 425/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1148 - accuracy: 0.9626 - auc: 0.9861 - val_loss: 0.0847 - val_accuracy: 0.9781 - val_auc: 0.9927
# Epoch 426/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9638 - auc: 0.9846 - val_loss: 0.0856 - val_accuracy: 0.9805 - val_auc: 0.9928
# Epoch 427/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1114 - accuracy: 0.9685 - auc: 0.9853 - val_loss: 0.0813 - val_accuracy: 0.9805 - val_auc: 0.9933
# Epoch 428/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9682 - auc: 0.9844 - val_loss: 0.0844 - val_accuracy: 0.9781 - val_auc: 0.9928
# Epoch 429/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9609 - auc: 0.9823 - val_loss: 0.0813 - val_accuracy: 0.9757 - val_auc: 0.9932
# Epoch 430/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.9733 - auc: 0.9854 - val_loss: 0.0955 - val_accuracy: 0.9659 - val_auc: 0.9909
# Epoch 431/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9596 - auc: 0.9843 - val_loss: 0.0810 - val_accuracy: 0.9781 - val_auc: 0.9928
# Epoch 432/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9673 - auc: 0.9845 - val_loss: 0.0831 - val_accuracy: 0.9732 - val_auc: 0.9937
# Epoch 433/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1167 - accuracy: 0.9655 - auc: 0.9835 - val_loss: 0.0832 - val_accuracy: 0.9732 - val_auc: 0.9923
# Epoch 434/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9696 - auc: 0.9874 - val_loss: 0.0831 - val_accuracy: 0.9781 - val_auc: 0.9928
# Epoch 435/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1126 - accuracy: 0.9651 - auc: 0.9853 - val_loss: 0.0808 - val_accuracy: 0.9830 - val_auc: 0.9932
# Epoch 436/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1037 - accuracy: 0.9693 - auc: 0.9875 - val_loss: 0.0860 - val_accuracy: 0.9757 - val_auc: 0.9915
# Epoch 437/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1168 - accuracy: 0.9687 - auc: 0.9846 - val_loss: 0.0874 - val_accuracy: 0.9732 - val_auc: 0.9921
# Epoch 438/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.9647 - auc: 0.9825 - val_loss: 0.0827 - val_accuracy: 0.9805 - val_auc: 0.9925
# Epoch 439/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1047 - accuracy: 0.9688 - auc: 0.9866 - val_loss: 0.0864 - val_accuracy: 0.9757 - val_auc: 0.9904
# Epoch 440/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9623 - auc: 0.9839 - val_loss: 0.0845 - val_accuracy: 0.9805 - val_auc: 0.9932
# Epoch 441/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 0.9662 - auc: 0.9851 - val_loss: 0.0833 - val_accuracy: 0.9781 - val_auc: 0.9933
# Epoch 442/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9663 - auc: 0.9845 - val_loss: 0.0864 - val_accuracy: 0.9708 - val_auc: 0.9923
# Epoch 443/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1115 - accuracy: 0.9680 - auc: 0.9863 - val_loss: 0.0816 - val_accuracy: 0.9781 - val_auc: 0.9930
# Epoch 444/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.9653 - auc: 0.9834 - val_loss: 0.0813 - val_accuracy: 0.9805 - val_auc: 0.9928
# Epoch 445/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1135 - accuracy: 0.9657 - auc: 0.9841 - val_loss: 0.0873 - val_accuracy: 0.9732 - val_auc: 0.9929
# Epoch 446/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1113 - accuracy: 0.9657 - auc: 0.9871 - val_loss: 0.0820 - val_accuracy: 0.9781 - val_auc: 0.9934
# Epoch 447/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0990 - accuracy: 0.9718 - auc: 0.9879 - val_loss: 0.0873 - val_accuracy: 0.9732 - val_auc: 0.9923
# Epoch 448/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9664 - auc: 0.9860 - val_loss: 0.0825 - val_accuracy: 0.9805 - val_auc: 0.9933
# Epoch 449/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9664 - auc: 0.9845 - val_loss: 0.0836 - val_accuracy: 0.9781 - val_auc: 0.9935
# Epoch 450/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9704 - auc: 0.9907 - val_loss: 0.0809 - val_accuracy: 0.9805 - val_auc: 0.9929
# Epoch 451/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9709 - auc: 0.9887 - val_loss: 0.0826 - val_accuracy: 0.9805 - val_auc: 0.9929
# Epoch 452/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1138 - accuracy: 0.9658 - auc: 0.9852 - val_loss: 0.1004 - val_accuracy: 0.9635 - val_auc: 0.9905
# Epoch 453/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1100 - accuracy: 0.9653 - auc: 0.9864 - val_loss: 0.0837 - val_accuracy: 0.9781 - val_auc: 0.9930
# Epoch 454/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9691 - auc: 0.9866 - val_loss: 0.0830 - val_accuracy: 0.9781 - val_auc: 0.9926
# Epoch 455/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9644 - auc: 0.9876 - val_loss: 0.0920 - val_accuracy: 0.9708 - val_auc: 0.9913
# Epoch 456/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1063 - accuracy: 0.9656 - auc: 0.9886 - val_loss: 0.0833 - val_accuracy: 0.9781 - val_auc: 0.9928
# Epoch 457/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1080 - accuracy: 0.9675 - auc: 0.9867 - val_loss: 0.0830 - val_accuracy: 0.9757 - val_auc: 0.9933
# Epoch 458/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9731 - auc: 0.9884 - val_loss: 0.0818 - val_accuracy: 0.9781 - val_auc: 0.9931
# Epoch 459/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1052 - accuracy: 0.9683 - auc: 0.9865 - val_loss: 0.0841 - val_accuracy: 0.9757 - val_auc: 0.9935
# Epoch 460/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1142 - accuracy: 0.9665 - auc: 0.9850 - val_loss: 0.0818 - val_accuracy: 0.9805 - val_auc: 0.9929
# Epoch 461/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9714 - auc: 0.9885 - val_loss: 0.0845 - val_accuracy: 0.9732 - val_auc: 0.9931
# Epoch 462/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9652 - auc: 0.9879 - val_loss: 0.0819 - val_accuracy: 0.9805 - val_auc: 0.9931
# Epoch 463/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1135 - accuracy: 0.9664 - auc: 0.9853 - val_loss: 0.0842 - val_accuracy: 0.9708 - val_auc: 0.9934
# Epoch 464/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1014 - accuracy: 0.9668 - auc: 0.9886 - val_loss: 0.0836 - val_accuracy: 0.9781 - val_auc: 0.9929
# Epoch 465/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1045 - accuracy: 0.9676 - auc: 0.9875 - val_loss: 0.1061 - val_accuracy: 0.9684 - val_auc: 0.9921
# Epoch 466/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1299 - accuracy: 0.9550 - auc: 0.9832 - val_loss: 0.0836 - val_accuracy: 0.9781 - val_auc: 0.9925
# Epoch 467/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9682 - auc: 0.9882 - val_loss: 0.0863 - val_accuracy: 0.9732 - val_auc: 0.9934
# Epoch 468/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1082 - accuracy: 0.9701 - auc: 0.9862 - val_loss: 0.0807 - val_accuracy: 0.9781 - val_auc: 0.9931
# Epoch 469/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1018 - accuracy: 0.9704 - auc: 0.9882 - val_loss: 0.0840 - val_accuracy: 0.9757 - val_auc: 0.9912
# Epoch 470/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9640 - auc: 0.9859 - val_loss: 0.0794 - val_accuracy: 0.9805 - val_auc: 0.9931
# Epoch 471/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1108 - accuracy: 0.9671 - auc: 0.9867 - val_loss: 0.0859 - val_accuracy: 0.9757 - val_auc: 0.9934
# Epoch 472/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9670 - auc: 0.9873 - val_loss: 0.0799 - val_accuracy: 0.9805 - val_auc: 0.9935
# Epoch 473/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9618 - auc: 0.9840 - val_loss: 0.0831 - val_accuracy: 0.9781 - val_auc: 0.9933
# Epoch 474/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1095 - accuracy: 0.9682 - auc: 0.9871 - val_loss: 0.0805 - val_accuracy: 0.9757 - val_auc: 0.9935
# Epoch 475/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1193 - accuracy: 0.9647 - auc: 0.9824 - val_loss: 0.0799 - val_accuracy: 0.9781 - val_auc: 0.9939
# Epoch 476/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.9754 - auc: 0.9881 - val_loss: 0.0792 - val_accuracy: 0.9805 - val_auc: 0.9927
# Epoch 477/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1063 - accuracy: 0.9686 - auc: 0.9856 - val_loss: 0.0818 - val_accuracy: 0.9757 - val_auc: 0.9936
# Epoch 478/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1056 - accuracy: 0.9668 - auc: 0.9867 - val_loss: 0.0837 - val_accuracy: 0.9757 - val_auc: 0.9931
# Epoch 479/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0994 - accuracy: 0.9710 - auc: 0.9878 - val_loss: 0.0891 - val_accuracy: 0.9732 - val_auc: 0.9911
# Epoch 480/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.9693 - auc: 0.9873 - val_loss: 0.0802 - val_accuracy: 0.9781 - val_auc: 0.9921
# Epoch 481/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.9668 - auc: 0.9850 - val_loss: 0.0853 - val_accuracy: 0.9732 - val_auc: 0.9923
# Epoch 482/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9633 - auc: 0.9820 - val_loss: 0.0866 - val_accuracy: 0.9781 - val_auc: 0.9924
# Epoch 483/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 0.9724 - auc: 0.9867 - val_loss: 0.0804 - val_accuracy: 0.9805 - val_auc: 0.9937
# Epoch 484/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9711 - auc: 0.9877 - val_loss: 0.0826 - val_accuracy: 0.9757 - val_auc: 0.9936
# Epoch 485/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1205 - accuracy: 0.9649 - auc: 0.9845 - val_loss: 0.0785 - val_accuracy: 0.9805 - val_auc: 0.9936
# Epoch 486/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9695 - auc: 0.9867 - val_loss: 0.0805 - val_accuracy: 0.9805 - val_auc: 0.9936
# Epoch 487/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1108 - accuracy: 0.9670 - auc: 0.9852 - val_loss: 0.0841 - val_accuracy: 0.9757 - val_auc: 0.9938
# Epoch 488/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1013 - accuracy: 0.9676 - auc: 0.9881 - val_loss: 0.0831 - val_accuracy: 0.9781 - val_auc: 0.9934
# Epoch 489/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1052 - accuracy: 0.9707 - auc: 0.9872 - val_loss: 0.0865 - val_accuracy: 0.9732 - val_auc: 0.9931
# Epoch 490/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1216 - accuracy: 0.9645 - auc: 0.9842 - val_loss: 0.0814 - val_accuracy: 0.9757 - val_auc: 0.9930
# Epoch 491/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9611 - auc: 0.9817 - val_loss: 0.0886 - val_accuracy: 0.9684 - val_auc: 0.9913
# Epoch 492/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1122 - accuracy: 0.9627 - auc: 0.9866 - val_loss: 0.0823 - val_accuracy: 0.9781 - val_auc: 0.9932
# Epoch 493/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9699 - auc: 0.9868 - val_loss: 0.0823 - val_accuracy: 0.9732 - val_auc: 0.9933
# Epoch 494/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0995 - accuracy: 0.9712 - auc: 0.9879 - val_loss: 0.0861 - val_accuracy: 0.9708 - val_auc: 0.9931
# Epoch 495/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1051 - accuracy: 0.9676 - auc: 0.9859 - val_loss: 0.0889 - val_accuracy: 0.9732 - val_auc: 0.9930
# Epoch 496/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9636 - auc: 0.9861 - val_loss: 0.0928 - val_accuracy: 0.9659 - val_auc: 0.9915
# Epoch 497/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9670 - auc: 0.9871 - val_loss: 0.0824 - val_accuracy: 0.9757 - val_auc: 0.9932
# Epoch 498/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9686 - auc: 0.9860 - val_loss: 0.0794 - val_accuracy: 0.9781 - val_auc: 0.9933
# Epoch 499/500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1285 - accuracy: 0.9634 - auc: 0.9820 - val_loss: 0.0826 - val_accuracy: 0.9805 - val_auc: 0.9936
# Epoch 500/500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.9681 - auc: 0.9859 - val_loss: 0.1060 - val_accuracy: 0.9611 - val_auc: 0.9891

# %%
score = model.evaluate(X_test,y_test, verbose=1)
print(score)
print('Test accuracy:', score[1])
# Out:
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1663 - accuracy: 0.9526 - auc: 0.9709
# [0.16627217829227448, 0.9525547623634338, 0.9709251523017883]
# Test accuracy: 0.9525547623634338

# %%
model.save("ver1.9")
# Out:
# INFO:tensorflow:Assets written to: ver1.9/assets

# %%
from keras.models import load_model
prevModel = load_model('ver1.8')

# %%
score = prevModel.evaluate(X_train,y_train, verbose=1)
print(score)
print('Test accuracy:', score[1])
# Out:
# 90/90 [==============================] - 0s 1ms/step - loss: 0.0939 - accuracy: 0.9687 - auc: 0.9929
# [0.09390673786401749, 0.968684732913971, 0.9929434657096863]
# Test accuracy: 0.968684732913971

# %%
prevModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25)                400
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                780
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,821
# Trainable params: 1,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !ls
# Out:
#  2018MT60795_it.pdf		   Synthetic_data.csv
# 'Colab Notebooks'		  'Untitled document.gdoc'
# 'Getting started.pdf'		  'Untitled presentation.gslides'
# 'iaw-edau-jme – 9 Feb 2021.gjam'   ver1.2
# 'ift-djtf-qko – 1 Mar 2021.gjam'   ver1.3
#  pca_data.csv			   ver1.4
